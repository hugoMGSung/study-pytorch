# %%
import cv2

cap = cv2.VideoCapture(0)
cap.set(3, 640)
cap.set(4, 480)

while True:
    ret, img= cap.read()
    cv2.imshow('Webcam', img)

    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
from ultralytics import YOLO
model = YOLO("yolo-Weights/yolov8n.pt")

# %%
classNames = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat",
              "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
              "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella",
              "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat",
              "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup",
              "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli",
              "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed",
              "diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone",
              "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors",
              "teddy bear", "hair drier", "toothbrush"
              ]

# %%
import cv2

cap = cv2.VideoCapture(0)
cap.set(3, 640)
cap.set(4, 480)

while True:
    ret, img= cap.read()
    results = model(img, stream=True)

    cv2.imshow('Webcam', results)

    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[4], line 11
#       8 ret, img= cap.read()
#       9 results = model(img, stream=True)
# ---> 11 cv2.imshow('Webcam', results)
#      13 if cv2.waitKey(1) == ord('q'):
#      14     break
#
# File c:\Users\perso\.pyenv\pyenv-win\versions\3.11.9\Lib\site-packages\ultralytics\utils\patches.py:56, in imshow(winname, mat)
#      48 def imshow(winname: str, mat: np.ndarray):
#      49     """
#      50     Displays an image in the specified window.
#      51
#    (...)
#      54         mat (np.ndarray): Image to be shown.
#      55     """
# ---> 56     _imshow(winname.encode("unicode_escape").decode(), mat)
#
# error: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imshow'
# > Overload resolution failed:
# >  - mat is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::cuda::GpuMat> for argument 'mat'
# >  - Expected Ptr<cv::UMat> for argument 'mat'

# %%
from ultralytics import YOLO
import cv2
import math 
# start webcam
cap = cv2.VideoCapture(0)
cap.set(3, 640)
cap.set(4, 480)

# model
model = YOLO("yolo-Weights/yolov8n.pt")

# object classes
classNames = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat",
				"traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
				"dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella",
				"handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat",
				"baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup",
				"fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli",
				"carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed",
				"diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone",
				"microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors",
				"teddy bear", "hair drier", "toothbrush"]


while True:
	success, img = cap.read()
	results = model(img, stream=True)

	# coordinates
	for r in results:
		boxes = r.boxes

		for box in boxes:
			# bounding box
			x1, y1, x2, y2 = box.xyxy[0]
			x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2) # convert to int values

			# put box in cam
			cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 255), 3)

			# confidence
			confidence = math.ceil((box.conf[0]*100))/100
			print("Confidence --->",confidence)

			# class name
			cls = int(box.cls[0])
			print("Class name -->", classNames[cls])

			# object details
			org = [x1, y1]
			font = cv2.FONT_HERSHEY_SIMPLEX
			fontScale = 1
			color = (255, 0, 0)
			thickness = 2

			cv2.putText(img, classNames[cls], org, font, fontScale, color, thickness)

	cv2.imshow('Webcam', img)
	if cv2.waitKey(1) == ord('q'):
		break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 2 kites, 11.3ms
# Confidence ---> 0.39
# Class name --> kite
# Confidence ---> 0.29
# Class name --> kite
# Speed: 2.0ms preprocess, 11.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 kite, 19.6ms
# Confidence ---> 0.36
# Class name --> kite
# Speed: 1.0ms preprocess, 19.6ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 17.1ms
# Speed: 1.6ms preprocess, 17.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 15.8ms
# Speed: 2.0ms preprocess, 15.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 16.7ms
# Speed: 1.0ms preprocess, 16.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 18.0ms
# Speed: 1.6ms preprocess, 18.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 14.8ms
# Speed: 2.0ms preprocess, 14.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.3ms
# Speed: 1.0ms preprocess, 8.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 10.3ms
# Speed: 1.0ms preprocess, 10.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 10.3ms
# Speed: 2.0ms preprocess, 10.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.3ms
# Speed: 1.9ms preprocess, 9.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 10.4ms
# Confidence ---> 0.58
# Class name --> person
# Confidence ---> 0.29
# Class name --> person
# Speed: 1.5ms preprocess, 10.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 9.3ms
# Confidence ---> 0.58
# Class name --> person
# Speed: 1.9ms preprocess, 9.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 9.3ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.0ms preprocess, 9.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 13.8ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 2.0ms preprocess, 13.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.3ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 2.0ms preprocess, 10.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.3ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.0ms preprocess, 10.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 9.3ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.9ms preprocess, 9.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 9.3ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.9ms preprocess, 9.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 9.3ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.0ms preprocess, 9.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.3ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.9ms preprocess, 10.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.3ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.0ms preprocess, 10.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.3ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.0ms preprocess, 10.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 9.3ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.9ms preprocess, 9.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 8.7ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 1.6ms preprocess, 8.7ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 8.7ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.6ms preprocess, 8.7ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 9.3ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 2.5ms preprocess, 9.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 9.3ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 2.0ms preprocess, 9.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.3ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 1.0ms preprocess, 10.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.3ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.0ms preprocess, 10.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 9.3ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 1.0ms preprocess, 9.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 9.3ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.0ms preprocess, 9.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 16.7ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 1.0ms preprocess, 16.7ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.4ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.0ms preprocess, 10.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 8.7ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 1.6ms preprocess, 8.7ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 8.7ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 1.1ms preprocess, 8.7ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 9.3ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.0ms preprocess, 9.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.3ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.0ms preprocess, 10.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 9.9ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 2.0ms preprocess, 9.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.3ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.0ms preprocess, 10.3ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.3ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.0ms preprocess, 10.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.3ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.0ms preprocess, 11.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.3ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 1.0ms preprocess, 10.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 11.3ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.38
# Class name --> cell phone
# Speed: 1.0ms preprocess, 11.3ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 10.3ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.53
# Class name --> cell phone
# Speed: 1.6ms preprocess, 10.3ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 9.9ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.31
# Class name --> cell phone
# Speed: 1.7ms preprocess, 9.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 10.4ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.58
# Class name --> cell phone
# Speed: 1.6ms preprocess, 10.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 9.1ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.33
# Class name --> cell phone
# Speed: 1.6ms preprocess, 9.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 9.4ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 2.5ms preprocess, 9.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 11.3ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.76
# Class name --> cell phone
# Speed: 2.5ms preprocess, 11.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 18.1ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.26
# Class name --> cell phone
# Speed: 2.6ms preprocess, 18.1ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 19.6ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 1.9ms preprocess, 19.6ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 17.7ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.51
# Class name --> cell phone
# Speed: 2.0ms preprocess, 17.7ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 17.7ms
# Confidence ---> 0.95
# Class name --> cell phone
# Confidence ---> 0.83
# Class name --> person
# Speed: 2.0ms preprocess, 17.7ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 17.1ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.76
# Class name --> cell phone
# Speed: 1.0ms preprocess, 17.1ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 12.3ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.4
# Class name --> cell phone
# Speed: 2.0ms preprocess, 12.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 9.3ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.87
# Class name --> cell phone
# Speed: 1.9ms preprocess, 9.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 10.3ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.7
# Class name --> cell phone
# Speed: 1.0ms preprocess, 10.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 10.3ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.91
# Class name --> cell phone
# Speed: 1.0ms preprocess, 10.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 10.4ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.82
# Class name --> cell phone
# Speed: 1.0ms preprocess, 10.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 10.3ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.87
# Class name --> cell phone
# Speed: 1.0ms preprocess, 10.3ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 11.3ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.84
# Class name --> cell phone
# Speed: 2.5ms preprocess, 11.3ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 10.3ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.5
# Class name --> cell phone
# Speed: 1.6ms preprocess, 10.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 19.7ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 2.5ms preprocess, 19.7ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 10.3ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.31
# Class name --> person
# Speed: 2.0ms preprocess, 10.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 teddy bear, 10.3ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.32
# Class name --> teddy bear
# Speed: 1.0ms preprocess, 10.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 9.8ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.28
# Class name --> person
# Speed: 1.0ms preprocess, 9.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 18.6ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.0ms preprocess, 18.6ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.8ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 0.9ms preprocess, 10.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.3ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.0ms preprocess, 10.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.3ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 0.9ms preprocess, 10.3ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.3ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 1.0ms preprocess, 10.3ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.3ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.0ms preprocess, 10.3ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.3ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 1.0ms preprocess, 11.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.3ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 2.0ms preprocess, 10.3ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 11.3ms
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.47
# Class name --> person
# Confidence ---> 0.35
# Class name --> person
# Speed: 1.0ms preprocess, 11.3ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.3ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.0ms preprocess, 10.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 10.4ms
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.27
# Class name --> cell phone
# Speed: 1.5ms preprocess, 10.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tie, 11.9ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.29
# Class name --> tie
# Speed: 0.0ms preprocess, 11.9ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tie, 1 cell phone, 18.1ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.37
# Class name --> tie
# Confidence ---> 0.3
# Class name --> cell phone
# Speed: 2.5ms preprocess, 18.1ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 17.8ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.53
# Class name --> cell phone
# Speed: 2.0ms preprocess, 17.8ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 10.3ms
# Confidence ---> 0.94
# Class name --> cell phone
# Confidence ---> 0.78
# Class name --> person
# Speed: 1.0ms preprocess, 10.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 11.3ms
# Confidence ---> 0.92
# Class name --> cell phone
# Confidence ---> 0.85
# Class name --> person
# Speed: 1.0ms preprocess, 11.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 10.3ms
# Confidence ---> 0.94
# Class name --> cell phone
# Confidence ---> 0.84
# Class name --> person
# Speed: 2.0ms preprocess, 10.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 10.3ms
# Confidence ---> 0.94
# Class name --> cell phone
# Confidence ---> 0.87
# Class name --> person
# Speed: 2.0ms preprocess, 10.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 13.8ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.85
# Class name --> cell phone
# Speed: 2.0ms preprocess, 13.8ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 13.8ms
# Confidence ---> 0.89
# Class name --> cell phone
# Confidence ---> 0.86
# Class name --> person
# Speed: 1.0ms preprocess, 13.8ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 10.3ms
# Confidence ---> 0.89
# Class name --> cell phone
# Confidence ---> 0.86
# Class name --> person
# Speed: 1.0ms preprocess, 10.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 10.3ms
# Confidence ---> 0.89
# Class name --> cell phone
# Confidence ---> 0.87
# Class name --> person
# Speed: 1.0ms preprocess, 10.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 10.4ms
# Confidence ---> 0.9
# Class name --> cell phone
# Confidence ---> 0.88
# Class name --> person
# Speed: 1.0ms preprocess, 10.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 10.4ms
# Confidence ---> 0.89
# Class name --> cell phone
# Confidence ---> 0.88
# Class name --> person
# Speed: 1.0ms preprocess, 10.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 10.4ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.81
# Class name --> cell phone
# Speed: 0.9ms preprocess, 10.4ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 10.4ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.69
# Class name --> cell phone
# Speed: 0.9ms preprocess, 10.4ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 12.0ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.42
# Class name --> cell phone
# Speed: 0.0ms preprocess, 12.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 10.3ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.33
# Class name --> cell phone
# Speed: 2.5ms preprocess, 10.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 15.9ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.48
# Class name --> cell phone
# Speed: 1.0ms preprocess, 15.9ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 11.4ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.44
# Class name --> cell phone
# Speed: 1.0ms preprocess, 11.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 11.3ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.54
# Class name --> cell phone
# Speed: 0.9ms preprocess, 11.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 11.3ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.79
# Class name --> cell phone
# Speed: 1.0ms preprocess, 11.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 10.3ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.83
# Class name --> cell phone
# Speed: 1.0ms preprocess, 10.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 10.3ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.8
# Class name --> cell phone
# Speed: 0.9ms preprocess, 10.3ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 10.3ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.62
# Class name --> cell phone
# Speed: 0.9ms preprocess, 10.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 15.2ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.69
# Class name --> cell phone
# Speed: 1.5ms preprocess, 15.2ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 11.3ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.83
# Class name --> cell phone
# Speed: 1.0ms preprocess, 11.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 10.4ms
# Confidence ---> 0.89
# Class name --> cell phone
# Confidence ---> 0.84
# Class name --> person
# Speed: 2.0ms preprocess, 10.4ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 11.3ms
# Confidence ---> 0.89
# Class name --> cell phone
# Confidence ---> 0.84
# Class name --> person
# Speed: 1.6ms preprocess, 11.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 11.3ms
# Confidence ---> 0.93
# Class name --> cell phone
# Confidence ---> 0.81
# Class name --> person
# Speed: 1.0ms preprocess, 11.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 10.9ms
# Confidence ---> 0.88
# Class name --> cell phone
# Confidence ---> 0.83
# Class name --> person
# Speed: 2.0ms preprocess, 10.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 10.4ms
# Confidence ---> 0.83
# Class name --> cell phone
# Confidence ---> 0.83
# Class name --> person
# Speed: 2.5ms preprocess, 10.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 11.3ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.75
# Class name --> cell phone
# Speed: 1.0ms preprocess, 11.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 11.3ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.79
# Class name --> cell phone
# Speed: 1.0ms preprocess, 11.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 12.8ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.78
# Class name --> cell phone
# Speed: 1.2ms preprocess, 12.8ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 11.3ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.85
# Class name --> cell phone
# Speed: 2.0ms preprocess, 11.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 11.0ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.8
# Class name --> cell phone
# Speed: 1.7ms preprocess, 11.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 11.2ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.86
# Class name --> cell phone
# Speed: 1.0ms preprocess, 11.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 11.3ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.55
# Class name --> cell phone
# Speed: 1.0ms preprocess, 11.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 11.3ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.6
# Class name --> cell phone
# Speed: 1.0ms preprocess, 11.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 20.6ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.59
# Class name --> cell phone
# Speed: 2.5ms preprocess, 20.6ms inference, 4.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 11.3ms
# Confidence ---> 0.94
# Class name --> cell phone
# Confidence ---> 0.83
# Class name --> person
# Speed: 1.0ms preprocess, 11.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 11.2ms
# Confidence ---> 0.95
# Class name --> cell phone
# Confidence ---> 0.8
# Class name --> person
# Speed: 1.6ms preprocess, 11.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 11.3ms
# Confidence ---> 0.89
# Class name --> cell phone
# Confidence ---> 0.8
# Class name --> person
# Speed: 1.0ms preprocess, 11.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 11.4ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.78
# Class name --> cell phone
# Speed: 1.9ms preprocess, 11.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 11.2ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.72
# Class name --> cell phone
# Speed: 1.7ms preprocess, 11.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 11.3ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.72
# Class name --> cell phone
# Speed: 1.0ms preprocess, 11.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 11.3ms
# Confidence ---> 0.92
# Class name --> cell phone
# Confidence ---> 0.88
# Class name --> person
# Speed: 1.9ms preprocess, 11.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 11.3ms
# Confidence ---> 0.9
# Class name --> cell phone
# Confidence ---> 0.87
# Class name --> person
# Speed: 1.0ms preprocess, 11.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 11.3ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.78
# Class name --> cell phone
# Speed: 1.0ms preprocess, 11.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 11.3ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.73
# Class name --> cell phone
# Speed: 1.0ms preprocess, 11.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 11.3ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.48
# Class name --> cell phone
# Speed: 1.0ms preprocess, 11.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 11.3ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.54
# Class name --> cell phone
# Speed: 1.0ms preprocess, 11.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 11.9ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.78
# Class name --> cell phone
# Speed: 1.0ms preprocess, 11.9ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 11.2ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.53
# Class name --> cell phone
# Speed: 1.1ms preprocess, 11.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 11.3ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.68
# Class name --> cell phone
# Speed: 2.5ms preprocess, 11.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 12.3ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.52
# Class name --> cell phone
# Speed: 1.0ms preprocess, 12.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 11.3ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.52
# Class name --> cell phone
# Speed: 1.9ms preprocess, 11.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 11.3ms
# Confidence ---> 0.87
# Class name --> cell phone
# Confidence ---> 0.84
# Class name --> person
# Speed: 1.9ms preprocess, 11.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 15.1ms
# Confidence ---> 0.92
# Class name --> cell phone
# Confidence ---> 0.88
# Class name --> person
# Speed: 1.0ms preprocess, 15.1ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 15.7ms
# Confidence ---> 0.93
# Class name --> cell phone
# Confidence ---> 0.85
# Class name --> person
# Speed: 2.0ms preprocess, 15.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 17.7ms
# Confidence ---> 0.91
# Class name --> cell phone
# Confidence ---> 0.81
# Class name --> person
# Speed: 1.0ms preprocess, 17.7ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cat, 1 cell phone, 11.3ms
# Confidence ---> 0.88
# Class name --> cell phone
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.31
# Class name --> cat
# Speed: 1.0ms preprocess, 11.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cat, 1 cell phone, 17.7ms
# Confidence ---> 0.9
# Class name --> cell phone
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.3
# Class name --> cat
# Speed: 1.0ms preprocess, 17.7ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cat, 1 cell phone, 17.6ms
# Confidence ---> 0.9
# Class name --> cell phone
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.48
# Class name --> cat
# Speed: 1.0ms preprocess, 17.6ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cat, 1 cell phone, 17.1ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.81
# Class name --> cell phone
# Confidence ---> 0.47
# Class name --> cat
# Speed: 1.6ms preprocess, 17.1ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 17.1ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.6
# Class name --> cell phone
# Speed: 1.9ms preprocess, 17.1ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cat, 1 cell phone, 16.8ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.82
# Class name --> cell phone
# Confidence ---> 0.28
# Class name --> cat
# Speed: 1.0ms preprocess, 16.8ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 16.8ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.85
# Class name --> cell phone
# Speed: 2.0ms preprocess, 16.8ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 17.7ms
# Confidence ---> 0.91
# Class name --> cell phone
# Confidence ---> 0.86
# Class name --> person
# Speed: 0.9ms preprocess, 17.7ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 11.3ms
# Confidence ---> 0.91
# Class name --> cell phone
# Confidence ---> 0.86
# Class name --> person
# Speed: 1.0ms preprocess, 11.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 15.2ms
# Confidence ---> 0.92
# Class name --> cell phone
# Confidence ---> 0.86
# Class name --> person
# Speed: 1.8ms preprocess, 15.2ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 11.4ms
# Confidence ---> 0.88
# Class name --> cell phone
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.9ms preprocess, 11.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 11.3ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.8
# Class name --> cell phone
# Speed: 1.0ms preprocess, 11.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 11.4ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.8
# Class name --> cell phone
# Speed: 1.0ms preprocess, 11.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 11.3ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.79
# Class name --> cell phone
# Speed: 2.0ms preprocess, 11.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 10.3ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.79
# Class name --> cell phone
# Speed: 1.9ms preprocess, 10.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 10.3ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.72
# Class name --> cell phone
# Speed: 1.9ms preprocess, 10.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 10.3ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.71
# Class name --> cell phone
# Speed: 2.0ms preprocess, 10.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 10.3ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.84
# Class name --> cell phone
# Speed: 2.0ms preprocess, 10.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 15.8ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.8
# Class name --> cell phone
# Speed: 0.9ms preprocess, 15.8ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cat, 1 banana, 10.8ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.66
# Class name --> cat
# Confidence ---> 0.5
# Class name --> banana
# Speed: 1.0ms preprocess, 10.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 15.7ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.39
# Class name --> cell phone
# Speed: 1.0ms preprocess, 15.7ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cat, 1 cell phone, 10.4ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.59
# Class name --> cell phone
# Confidence ---> 0.33
# Class name --> cat
# Speed: 1.0ms preprocess, 10.4ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 19.1ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.48
# Class name --> cell phone
# Speed: 1.6ms preprocess, 19.1ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cat, 1 cell phone, 11.3ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.79
# Class name --> cell phone
# Confidence ---> 0.27
# Class name --> cat
# Speed: 1.0ms preprocess, 11.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 11.3ms
# Confidence ---> 0.89
# Class name --> cell phone
# Confidence ---> 0.87
# Class name --> person
# Speed: 1.0ms preprocess, 11.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 10.4ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.86
# Class name --> cell phone
# Speed: 1.0ms preprocess, 10.4ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 11.3ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.85
# Class name --> cell phone
# Speed: 1.0ms preprocess, 11.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cat, 1 cell phone, 11.3ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.68
# Class name --> cell phone
# Confidence ---> 0.34
# Class name --> cat
# Speed: 1.0ms preprocess, 11.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 12.3ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.56
# Class name --> cell phone
# Speed: 1.0ms preprocess, 12.3ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 10.3ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.52
# Class name --> cell phone
# Speed: 1.0ms preprocess, 10.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 11.9ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.5
# Class name --> cell phone
# Speed: 1.0ms preprocess, 11.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 11.8ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.69
# Class name --> cell phone
# Speed: 0.0ms preprocess, 11.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 11.3ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.84
# Class name --> cell phone
# Speed: 1.5ms preprocess, 11.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 11.3ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.82
# Class name --> cell phone
# Speed: 1.0ms preprocess, 11.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 11.3ms
# Confidence ---> 0.87
# Class name --> cell phone
# Confidence ---> 0.86
# Class name --> person
# Speed: 1.0ms preprocess, 11.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 11.3ms
# Confidence ---> 0.89
# Class name --> cell phone
# Confidence ---> 0.86
# Class name --> person
# Speed: 1.0ms preprocess, 11.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 10.3ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.81
# Class name --> cell phone
# Speed: 1.0ms preprocess, 10.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 11.9ms
# Confidence ---> 0.91
# Class name --> cell phone
# Confidence ---> 0.86
# Class name --> person
# Speed: 1.0ms preprocess, 11.9ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 11.5ms
# Confidence ---> 0.92
# Class name --> cell phone
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.28
# Class name --> person
# Speed: 1.7ms preprocess, 11.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 12.0ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.82
# Class name --> cell phone
# Speed: 2.2ms preprocess, 12.0ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 11.0ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.84
# Class name --> cell phone
# Speed: 1.7ms preprocess, 11.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 11.3ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.83
# Class name --> cell phone
# Speed: 1.0ms preprocess, 11.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 10.8ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.8
# Class name --> cell phone
# Speed: 1.0ms preprocess, 10.8ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 11.3ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.8
# Class name --> cell phone
# Confidence ---> 0.33
# Class name --> person
# Speed: 1.0ms preprocess, 11.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 10.3ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.86
# Class name --> cell phone
# Speed: 1.0ms preprocess, 10.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 18.1ms
# Confidence ---> 0.87
# Class name --> cell phone
# Confidence ---> 0.87
# Class name --> person
# Speed: 1.6ms preprocess, 18.1ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 banana, 1 cell phone, 11.3ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.82
# Class name --> cell phone
# Confidence ---> 0.29
# Class name --> banana
# Speed: 1.0ms preprocess, 11.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 10.3ms
# Confidence ---> 0.92
# Class name --> cell phone
# Confidence ---> 0.89
# Class name --> person
# Speed: 2.5ms preprocess, 10.3ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 11.3ms
# Confidence ---> 0.93
# Class name --> cell phone
# Confidence ---> 0.87
# Class name --> person
# Speed: 1.9ms preprocess, 11.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 10.3ms
# Confidence ---> 0.92
# Class name --> cell phone
# Confidence ---> 0.88
# Class name --> person
# Speed: 1.9ms preprocess, 10.3ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 11.3ms
# Confidence ---> 0.91
# Class name --> cell phone
# Confidence ---> 0.87
# Class name --> person
# Speed: 1.0ms preprocess, 11.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 11.3ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.85
# Class name --> cell phone
# Speed: 2.0ms preprocess, 11.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 11.3ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.85
# Class name --> cell phone
# Speed: 1.0ms preprocess, 11.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 10.3ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.71
# Class name --> cell phone
# Speed: 1.0ms preprocess, 10.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 11.4ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.81
# Class name --> cell phone
# Speed: 1.0ms preprocess, 11.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 11.3ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.77
# Class name --> cell phone
# Speed: 1.0ms preprocess, 11.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 13.2ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.76
# Class name --> cell phone
# Speed: 2.0ms preprocess, 13.2ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 13.8ms
# Confidence ---> 0.87
# Class name --> cell phone
# Confidence ---> 0.85
# Class name --> person
# Speed: 2.0ms preprocess, 13.8ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 11.3ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.56
# Class name --> cell phone
# Speed: 0.9ms preprocess, 11.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 10.3ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.86
# Class name --> cell phone
# Speed: 1.0ms preprocess, 10.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 10.3ms
# Confidence ---> 0.92
# Class name --> cell phone
# Confidence ---> 0.88
# Class name --> person
# Speed: 1.5ms preprocess, 10.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 10.4ms
# Confidence ---> 0.9
# Class name --> cell phone
# Confidence ---> 0.87
# Class name --> person
# Speed: 1.0ms preprocess, 10.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 10.3ms
# Confidence ---> 0.91
# Class name --> cell phone
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 2.0ms preprocess, 10.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 11.3ms
# Confidence ---> 0.91
# Class name --> cell phone
# Confidence ---> 0.88
# Class name --> person
# Speed: 1.0ms preprocess, 11.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 10.4ms
# Confidence ---> 0.9
# Class name --> cell phone
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.9ms preprocess, 10.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 10.3ms
# Confidence ---> 0.91
# Class name --> cell phone
# Confidence ---> 0.88
# Class name --> person
# Speed: 1.0ms preprocess, 10.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 10.3ms
# Confidence ---> 0.92
# Class name --> cell phone
# Confidence ---> 0.86
# Class name --> person
# Speed: 1.0ms preprocess, 10.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 10.9ms
# Confidence ---> 0.93
# Class name --> cell phone
# Confidence ---> 0.88
# Class name --> person
# Speed: 1.0ms preprocess, 10.9ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 10.3ms
# Confidence ---> 0.92
# Class name --> cell phone
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.9ms preprocess, 10.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 10.3ms
# Confidence ---> 0.92
# Class name --> cell phone
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.9ms preprocess, 10.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 10.3ms
# Confidence ---> 0.94
# Class name --> cell phone
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.28
# Class name --> person
# Speed: 1.0ms preprocess, 10.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 10.4ms
# Confidence ---> 0.93
# Class name --> cell phone
# Confidence ---> 0.86
# Class name --> person
# Speed: 2.5ms preprocess, 10.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 10.4ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.86
# Class name --> cell phone
# Confidence ---> 0.28
# Class name --> person
# Speed: 1.9ms preprocess, 10.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 11.9ms
# Confidence ---> 0.86
# Class name --> cell phone
# Confidence ---> 0.86
# Class name --> person
# Speed: 0.0ms preprocess, 11.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 11.8ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.84
# Class name --> cell phone
# Speed: 1.0ms preprocess, 11.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 10.3ms
# Confidence ---> 0.88
# Class name --> cell phone
# Confidence ---> 0.86
# Class name --> person
# Speed: 1.6ms preprocess, 10.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 11.4ms
# Confidence ---> 0.87
# Class name --> cell phone
# Confidence ---> 0.84
# Class name --> person
# Speed: 1.5ms preprocess, 11.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 10.4ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.81
# Class name --> cell phone
# Speed: 1.8ms preprocess, 10.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 10.5ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.77
# Class name --> cell phone
# Speed: 2.0ms preprocess, 10.5ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 10.4ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.68
# Class name --> cell phone
# Speed: 1.9ms preprocess, 10.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 10.3ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.74
# Class name --> cell phone
# Speed: 2.0ms preprocess, 10.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 10.3ms
# Confidence ---> 0.89
# Class name --> cell phone
# Confidence ---> 0.88
# Class name --> person
# Speed: 1.0ms preprocess, 10.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 10.8ms
# Confidence ---> 0.91
# Class name --> cell phone
# Confidence ---> 0.88
# Class name --> person
# ...
#
# 0: 480x640 1 person, 1 remote, 10.3ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.31
# Class name --> remote
# Speed: 2.0ms preprocess, 10.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 18.7ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.0ms preprocess, 18.7ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.3ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 2.5ms preprocess, 10.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 10.2ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.32
# Class name --> remote
# Speed: 1.6ms preprocess, 10.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 15.2ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 2.5ms preprocess, 15.2ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 15.2ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 2.0ms preprocess, 15.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.2ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.5ms preprocess, 11.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.3ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 2.5ms preprocess, 11.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.3ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.0ms preprocess, 12.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 19.6ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 2.0ms preprocess, 19.6ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.3ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 2.0ms preprocess, 12.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 13.2ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.0ms preprocess, 13.2ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.3ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 2.0ms preprocess, 12.3ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.3ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 2.0ms preprocess, 11.3ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.3ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.0ms preprocess, 12.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 15.7ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.0ms preprocess, 15.7ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 15.1ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 2.6ms preprocess, 15.1ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.3ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.5ms preprocess, 12.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.3ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 2.5ms preprocess, 10.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.3ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.0ms preprocess, 11.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 13.8ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 2.0ms preprocess, 13.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.3ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.0ms preprocess, 11.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 21.6ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.0ms preprocess, 21.6ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 18.7ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.0ms preprocess, 18.7ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.3ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 2.5ms preprocess, 10.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 21.6ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 1.0ms preprocess, 21.6ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 26.5ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 2.0ms preprocess, 26.5ms inference, 7.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 15.2ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 2.0ms preprocess, 15.2ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 13.2ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.0ms preprocess, 13.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.2ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.6ms preprocess, 11.2ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.3ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 0.9ms preprocess, 12.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.3ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 2.5ms preprocess, 11.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.3ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 2.0ms preprocess, 11.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.3ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.0ms preprocess, 11.3ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.3ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 2.0ms preprocess, 11.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.3ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 2.0ms preprocess, 11.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 13.8ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 2.9ms preprocess, 13.8ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 14.7ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 2.2ms preprocess, 14.7ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 16.6ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.6ms preprocess, 16.6ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 14.1ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 2.2ms preprocess, 14.1ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.6ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 2.3ms preprocess, 17.6ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 13.2ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.5ms preprocess, 13.2ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.8ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 2.0ms preprocess, 12.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 14.2ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 2.0ms preprocess, 14.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.3ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.0ms preprocess, 12.3ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.3ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 1.0ms preprocess, 12.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 13.2ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 2.5ms preprocess, 13.2ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.4ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 1.9ms preprocess, 11.4ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.3ms
# Confidence ---> 0.84
# Class name --> person
# Speed: 1.0ms preprocess, 12.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.3ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 2.0ms preprocess, 12.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 15.7ms
# Confidence ---> 0.79
# Class name --> person
# Speed: 1.9ms preprocess, 15.7ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 14.8ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 1.9ms preprocess, 14.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 13.8ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 2.0ms preprocess, 13.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.8ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 1.0ms preprocess, 11.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 14.2ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 1.5ms preprocess, 14.2ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.3ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 1.0ms preprocess, 12.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 13.2ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 1.6ms preprocess, 13.2ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.9ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.0ms preprocess, 11.9ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.3ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 1.5ms preprocess, 11.3ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 13.3ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 2.5ms preprocess, 13.3ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.4ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 2.0ms preprocess, 11.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.4ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 1.0ms preprocess, 11.4ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 18.7ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 2.0ms preprocess, 18.7ms inference, 4.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.2ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.0ms preprocess, 12.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.3ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.0ms preprocess, 12.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.8ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.0ms preprocess, 11.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.3ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 1.0ms preprocess, 11.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 13.8ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 1.0ms preprocess, 13.8ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.2ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 1.6ms preprocess, 12.2ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.3ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 2.5ms preprocess, 11.3ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.3ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 2.5ms preprocess, 12.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.4ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 2.0ms preprocess, 11.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 16.2ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 2.0ms preprocess, 16.2ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 21.6ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 1.9ms preprocess, 21.6ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.3ms
# Confidence ---> 0.84
# Class name --> person
# Speed: 2.0ms preprocess, 11.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.3ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 1.0ms preprocess, 11.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 14.2ms
# Confidence ---> 0.82
# Class name --> person
# Speed: 1.0ms preprocess, 14.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.3ms
# Confidence ---> 0.81
# Class name --> person
# Speed: 1.0ms preprocess, 12.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.3ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 1.0ms preprocess, 12.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.3ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 2.0ms preprocess, 11.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.3ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 1.0ms preprocess, 12.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 28.0ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 2.0ms preprocess, 28.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.2ms
# Confidence ---> 0.84
# Class name --> person
# Speed: 1.6ms preprocess, 12.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.7ms
# Confidence ---> 0.82
# Class name --> person
# Speed: 1.0ms preprocess, 12.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 13.3ms
# Confidence ---> 0.84
# Class name --> person
# Speed: 2.5ms preprocess, 13.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.3ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 2.0ms preprocess, 12.3ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.8ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 2.0ms preprocess, 11.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.7ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 2.0ms preprocess, 17.7ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.3ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 1.0ms preprocess, 11.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.3ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.0ms preprocess, 12.3ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 19.2ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 1.0ms preprocess, 19.2ms inference, 4.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.9ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.0ms preprocess, 11.9ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.8ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 1.0ms preprocess, 10.8ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.3ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 1.9ms preprocess, 11.3ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
