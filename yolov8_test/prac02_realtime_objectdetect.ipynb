# %%
import cv2

cap = cv2.VideoCapture(0)
cap.set(3, 640)
cap.set(4, 480)

while True:
    ret, img= cap.read()
    cv2.imshow('Webcam', img)

    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
from ultralytics import YOLO
model = YOLO("yolo-Weights/yolov8n.pt")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from ultralytics import YOLO
#       2 model = YOLO("yolo-Weights/yolov8n.pt")
#
# ModuleNotFoundError: No module named 'ultralytics'

# %%
classNames = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat",
              "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
              "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella",
              "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat",
              "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup",
              "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli",
              "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed",
              "diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone",
              "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors",
              "teddy bear", "hair drier", "toothbrush"
              ]

# %%
import cv2

cap = cv2.VideoCapture(0)
cap.set(3, 640)
cap.set(4, 480)

while True:
    ret, img= cap.read()
    results = model(img, stream=True)

    cv2.imshow('Webcam', results)

    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[4], line 11
#       8 ret, img= cap.read()
#       9 results = model(img, stream=True)
# ---> 11 cv2.imshow('Webcam', results)
#      13 if cv2.waitKey(1) == ord('q'):
#      14     break
#
# File d:\01_Programming\100_HugoBank\Mine\study-pytorch\pytorch_env\lib\site-packages\ultralytics\utils\patches.py:56, in imshow(winname, mat)
#      48 def imshow(winname: str, mat: np.ndarray):
#      49     """
#      50     Displays an image in the specified window.
#      51
#    (...)
#      54         mat (np.ndarray): Image to be shown.
#      55     """
# ---> 56     _imshow(winname.encode("unicode_escape").decode(), mat)
#
# error: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'imshow'
# > Overload resolution failed:
# >  - mat is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::cuda::GpuMat> for argument 'mat'
# >  - Expected Ptr<cv::UMat> for argument 'mat'

# %%
from ultralytics import YOLO
import cv2
import math 
# start webcam
cap = cv2.VideoCapture(0)
cap.set(3, 640)
cap.set(4, 480)

# model
model = YOLO("yolo-Weights/yolov8n.pt")

# object classes
classNames = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat",
				"traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
				"dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella",
				"handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat",
				"baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup",
				"fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli",
				"carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed",
				"diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone",
				"microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors",
				"teddy bear", "hair drier", "toothbrush"]


while True:
	success, img = cap.read()
	results = model(img, stream=True)

	# coordinates
	for r in results:
		boxes = r.boxes

		for box in boxes:
			# bounding box
			x1, y1, x2, y2 = box.xyxy[0]
			x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2) # convert to int values

			# put box in cam
			cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 255), 3)

			# confidence
			confidence = math.ceil((box.conf[0]*100))/100
			print("Confidence --->",confidence)

			# class name
			cls = int(box.cls[0])
			print("Class name -->", classNames[cls])

			# object details
			org = [x1, y1]
			font = cv2.FONT_HERSHEY_SIMPLEX
			fontScale = 1
			color = (255, 0, 0)
			thickness = 2

			cv2.putText(img, classNames[cls], org, font, fontScale, color, thickness)

	cv2.imshow('Webcam', img)
	if cv2.waitKey(1) == ord('q'):
		break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 person, 1 tv, 54.0ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.5
# Class name --> tvmonitor
# Speed: 6.0ms preprocess, 54.0ms inference, 160.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 14.0ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.29
# Class name --> tvmonitor
# Speed: 5.0ms preprocess, 14.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.0ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 2.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 12.0ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.26
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 12.0ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 9.0ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.29
# Class name --> tvmonitor
# Speed: 3.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 11.0ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.26
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 9.6ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 2.0ms preprocess, 9.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 10.0ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.28
# Class name --> tvmonitor
# Confidence ---> 0.28
# Class name --> tvmonitor
# Speed: 1.0ms preprocess, 10.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 10.0ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.26
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 10.0ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.28
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 9.0ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.32
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 11.0ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.34
# Class name --> tvmonitor
# Speed: 1.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 11.0ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.29
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 9.1ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.34
# Class name --> tvmonitor
# Confidence ---> 0.31
# Class name --> tvmonitor
# Speed: 1.0ms preprocess, 9.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 12.1ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.43
# Class name --> tvmonitor
# Confidence ---> 0.28
# Class name --> tvmonitor
# Speed: 1.1ms preprocess, 12.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 17.0ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.38
# Class name --> tvmonitor
# Confidence ---> 0.28
# Class name --> tvmonitor
# Speed: 3.0ms preprocess, 17.0ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 16.0ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.32
# Class name --> tvmonitor
# Confidence ---> 0.27
# Class name --> tvmonitor
# Speed: 3.0ms preprocess, 16.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 11.9ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.31
# Class name --> tvmonitor
# Speed: 1.6ms preprocess, 11.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 10.7ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.34
# Class name --> tvmonitor
# Speed: 1.0ms preprocess, 10.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 12.0ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.31
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 16.0ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.37
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 16.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 10.0ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.52
# Class name --> tvmonitor
# Speed: 3.0ms preprocess, 10.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 13.0ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.6
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 13.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 18.0ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.51
# Class name --> tvmonitor
# Speed: 1.9ms preprocess, 18.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 11.0ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.42
# Class name --> tvmonitor
# Confidence ---> 0.26
# Class name --> tvmonitor
# Speed: 2.1ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 19.0ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.4
# Class name --> tvmonitor
# Speed: 3.0ms preprocess, 19.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 10.0ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.44
# Class name --> tvmonitor
# Speed: 1.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 14.1ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.47
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 14.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 17.0ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.4
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 17.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 9.0ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.26
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 9.0ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 10.0ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.29
# Class name --> tvmonitor
# Speed: 2.4ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.0ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 2.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 9.0ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.37
# Class name --> tvmonitor
# Speed: 1.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 11.0ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.31
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 10.5ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.29
# Class name --> tvmonitor
# Speed: 1.0ms preprocess, 10.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 12.1ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.33
# Class name --> tvmonitor
# Speed: 1.0ms preprocess, 12.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 10.0ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.33
# Class name --> tvmonitor
# Speed: 1.0ms preprocess, 10.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 15.5ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.32
# Class name --> tvmonitor
# Confidence ---> 0.27
# Class name --> tvmonitor
# Speed: 1.0ms preprocess, 15.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 12.0ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.28
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 12.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.0ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 2.0ms preprocess, 11.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 17.5ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.27
# Class name --> tvmonitor
# Confidence ---> 0.26
# Class name --> tvmonitor
# Speed: 3.0ms preprocess, 17.5ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.3ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 1.8ms preprocess, 12.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.9ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 2.1ms preprocess, 10.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.1ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 3.0ms preprocess, 11.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 12.0ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.34
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 tvs, 24.1ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.38
# Class name --> tvmonitor
# Confidence ---> 0.35
# Class name --> tvmonitor
# Confidence ---> 0.3
# Class name --> tvmonitor
# Speed: 1.0ms preprocess, 24.1ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 tvs, 18.0ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.52
# Class name --> tvmonitor
# Confidence ---> 0.41
# Class name --> tvmonitor
# Confidence ---> 0.29
# Class name --> tvmonitor
# Speed: 3.0ms preprocess, 18.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 18.0ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.45
# Class name --> tvmonitor
# Confidence ---> 0.28
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 18.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 11.0ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.33
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 tvs, 11.2ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.49
# Class name --> tvmonitor
# Confidence ---> 0.32
# Class name --> tvmonitor
# Confidence ---> 0.31
# Class name --> tvmonitor
# Speed: 1.6ms preprocess, 11.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 12.0ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.36
# Class name --> tvmonitor
# Confidence ---> 0.34
# Class name --> tvmonitor
# Speed: 1.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 11.0ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.43
# Class name --> tvmonitor
# Confidence ---> 0.3
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 11.0ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.34
# Class name --> tvmonitor
# Speed: 3.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 13.0ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 13.5ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 2.0ms preprocess, 13.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.7ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.0ms preprocess, 12.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.0ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 2.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 21.0ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 3.0ms preprocess, 21.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.0ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 2.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 refrigerator, 12.0ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.31
# Class name --> refrigerator
# Speed: 1.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 refrigerator, 11.6ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.38
# Class name --> refrigerator
# Speed: 1.0ms preprocess, 11.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 refrigerator, 11.0ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.36
# Class name --> refrigerator
# Speed: 1.9ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 refrigerator, 12.0ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.27
# Class name --> refrigerator
# Speed: 2.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 refrigerator, 11.0ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.35
# Class name --> refrigerator
# Speed: 2.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 refrigerator, 12.0ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.33
# Class name --> refrigerator
# Confidence ---> 0.3
# Class name --> tvmonitor
# Confidence ---> 0.26
# Class name --> tvmonitor
# Speed: 1.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 1 refrigerator, 15.8ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.34
# Class name --> refrigerator
# Confidence ---> 0.29
# Class name --> tvmonitor
# Speed: 3.0ms preprocess, 15.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 1 refrigerator, 11.0ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.34
# Class name --> tvmonitor
# Confidence ---> 0.29
# Class name --> refrigerator
# Speed: 2.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 15.9ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.39
# Class name --> tvmonitor
# Speed: 3.1ms preprocess, 15.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 1 refrigerator, 13.0ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.33
# Class name --> refrigerator
# Confidence ---> 0.29
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 13.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 11.5ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.48
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 11.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 11.8ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.5
# Class name --> tvmonitor
# Confidence ---> 0.29
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 11.8ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 12.0ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.37
# Class name --> tvmonitor
# Confidence ---> 0.33
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 11.0ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.48
# Class name --> tvmonitor
# Confidence ---> 0.28
# Class name --> tvmonitor
# Speed: 3.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 16.0ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.49
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 16.0ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 12.0ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.42
# Class name --> tvmonitor
# Speed: 1.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 1 refrigerator, 13.1ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.38
# Class name --> tvmonitor
# Confidence ---> 0.26
# Class name --> refrigerator
# Speed: 2.0ms preprocess, 13.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 11.0ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.38
# Class name --> tvmonitor
# Speed: 1.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 11.0ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.38
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 12.1ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.29
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 12.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 13.0ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.26
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 12.7ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.29
# Class name --> tvmonitor
# Speed: 1.2ms preprocess, 12.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 13.0ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.36
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 11.0ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.26
# Class name --> tvmonitor
# Speed: 2.5ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 12.0ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.26
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 13.0ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.32
# Class name --> tvmonitor
# Speed: 1.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 11.5ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.29
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 11.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 11.9ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.31
# Class name --> tvmonitor
# Speed: 1.0ms preprocess, 11.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 16.0ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.39
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 16.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.5ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 3.0ms preprocess, 11.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 13.0ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 2.0ms preprocess, 13.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 24.0ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.29
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 24.0ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 10.7ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.3
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 10.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 11.0ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.26
# Class name --> tvmonitor
# Speed: 1.0ms preprocess, 11.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 12.0ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.26
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 13.2ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 2.0ms preprocess, 13.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 13.0ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 1.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 12.0ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.29
# Class name --> tvmonitor
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.0ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 1.0ms preprocess, 12.0ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.0ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 1.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.0ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 2.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.0ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 1.0ms preprocess, 17.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.0ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 1.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.3ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.7ms preprocess, 11.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.0ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 2.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.0ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 2.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.0ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 2.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.6ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 1.0ms preprocess, 17.6ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.9ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 1.0ms preprocess, 10.9ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.0ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 2.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 26.5ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.32
# Class name --> tvmonitor
# Speed: 3.0ms preprocess, 26.5ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 13.0ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.28
# Class name --> tvmonitor
# Speed: 1.6ms preprocess, 13.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.1ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 2.0ms preprocess, 11.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 13.9ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 2.1ms preprocess, 13.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 12.0ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.28
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10.9ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.0ms preprocess, 10.9ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.0ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 2.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 12.9ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.27
# Class name --> tvmonitor
# Speed: 1.9ms preprocess, 12.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 16.0ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.0ms preprocess, 16.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.0ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 2.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.0ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.0ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.0ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.0ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.0ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.0ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 11.0ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.26
# Class name --> tvmonitor
# Speed: 1.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 16.1ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.49
# Class name --> person
# Speed: 2.0ms preprocess, 16.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 11.0ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.57
# Class name --> person
# Speed: 2.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 teddy bear, 11.0ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.39
# Class name --> teddy bear
# Speed: 1.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 12.0ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.3
# Class name --> person
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 11.0ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.4
# Class name --> person
# Speed: 1.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 donut, 16.9ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.32
# Class name --> donut
# Confidence ---> 0.3
# Class name --> person
# Speed: 1.0ms preprocess, 16.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 donut, 11.0ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.66
# Class name --> donut
# Speed: 2.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.0ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 2.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.0ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 1.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 1 cell phone, 13.0ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.34
# Class name --> cell phone
# Confidence ---> 0.29
# Class name --> remote
# Speed: 1.0ms preprocess, 13.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cell phones, 21.0ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.33
# Class name --> cell phone
# Confidence ---> 0.27
# Class name --> cell phone
# Speed: 2.0ms preprocess, 21.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 1 cell phone, 11.0ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.26
# Class name --> cell phone
# Confidence ---> 0.26
# Class name --> tvmonitor
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 16.5ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.27
# Class name --> cell phone
# Speed: 1.0ms preprocess, 16.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 12.0ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.27
# Class name --> cell phone
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.2ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.7ms preprocess, 11.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.0ms
# Confidence ---> 0.84
# Class name --> person
# Speed: 2.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 12.0ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.27
# Class name --> remote
# Speed: 2.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.0ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 17.0ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 2.0ms preprocess, 17.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.0ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 15.6ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.28
# Class name --> remote
# Speed: 2.6ms preprocess, 15.6ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 12.0ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.28
# Class name --> remote
# Speed: 1.0ms preprocess, 12.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 1 cell phone, 12.0ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.29
# Class name --> remote
# Confidence ---> 0.28
# Class name --> cell phone
# Speed: 1.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 1 cell phone, 12.0ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.3
# Class name --> remote
# Confidence ---> 0.28
# Class name --> cell phone
# Speed: 1.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 12.0ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.27
# Class name --> remote
# Speed: 1.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 12.0ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.28
# Class name --> remote
# Speed: 3.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 14.0ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.34
# Class name --> remote
# Speed: 3.0ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 12.0ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.29
# Class name --> remote
# Speed: 1.0ms preprocess, 12.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 18.0ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 1.5ms preprocess, 18.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 12.2ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.3
# Class name --> cell phone
# Speed: 2.7ms preprocess, 12.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.5ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 3.0ms preprocess, 11.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 13.0ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.0ms preprocess, 13.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 13.0ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 2.0ms preprocess, 13.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 19.5ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 2.0ms preprocess, 19.5ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.0ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 2.0ms preprocess, 12.0ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 13.0ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 2.0ms preprocess, 13.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 19.0ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 2.6ms preprocess, 19.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.0ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 1.0ms preprocess, 12.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.6ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 2.0ms preprocess, 12.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 12.0ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.26
# Class name --> remote
# Speed: 4.0ms preprocess, 12.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 15.0ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 2.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 13.0ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 3.0ms preprocess, 13.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 15.0ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 2.0ms preprocess, 15.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.3ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 2.0ms preprocess, 12.3ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 13.2ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 3.0ms preprocess, 13.2ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 16.0ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.27
# Class name --> remote
# Speed: 2.0ms preprocess, 16.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 17.0ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.26
# Class name --> remote
# Speed: 2.0ms preprocess, 17.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.0ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 3.0ms preprocess, 12.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.0ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 2.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.5ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 1.0ms preprocess, 12.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 12.0ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.42
# Class name --> person
# Speed: 1.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 12.0ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.42
# Class name --> person
# Speed: 2.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.0ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 3.0ms preprocess, 12.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 13.0ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 2.0ms preprocess, 13.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 refrigerator, 13.4ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.27
# Class name --> refrigerator
# Speed: 1.4ms preprocess, 13.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 12.0ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.31
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 12.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 14.0ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 3.0ms preprocess, 14.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.0ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 3.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 12.0ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.26
# Class name --> tvmonitor
# Speed: 1.0ms preprocess, 12.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 11.0ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.26
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.0ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.0ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 2.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 13.1ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 2.0ms preprocess, 13.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.0ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 2.0ms preprocess, 12.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 26.5ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 2.0ms preprocess, 26.5ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 16.0ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 2.0ms preprocess, 16.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 18.5ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 3.0ms preprocess, 18.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.0ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 2.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.0ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 2.0ms preprocess, 12.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.0ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 2.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.0ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 3.0ms preprocess, 12.0ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.0ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 11.6ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.3
# Class name --> tvmonitor
# Speed: 1.0ms preprocess, 11.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 13.0ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.29
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 13.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 12.0ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.32
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 11.0ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 2.0ms preprocess, 11.0ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 17.0ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.27
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 17.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 12.0ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.31
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 11.5ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.31
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 11.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 13.0ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 12.0ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.28
# Class name --> tvmonitor
# Speed: 1.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 13.0ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.27
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.0ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.0ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 2.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 13.5ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 2.0ms preprocess, 13.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.0ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 2.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 13.3ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 2.0ms preprocess, 13.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 12.0ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 12.0ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.44
# Class name --> bottle
# Speed: 1.0ms preprocess, 12.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 12.0ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.78
# Class name --> bottle
# Speed: 1.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 12.0ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.88
# Class name --> bottle
# Speed: 2.0ms preprocess, 12.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 12.1ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.91
# Class name --> bottle
# Speed: 2.0ms preprocess, 12.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 11.7ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.91
# Class name --> bottle
# Speed: 2.0ms preprocess, 11.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 14.0ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.87
# Class name --> bottle
# Speed: 2.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 13.0ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.86
# Class name --> bottle
# Speed: 2.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 12.0ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.86
# Class name --> bottle
# Speed: 1.0ms preprocess, 12.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 16.3ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.82
# Class name --> bottle
# Speed: 3.2ms preprocess, 16.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 12.0ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.75
# Class name --> bottle
# Speed: 2.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 12.0ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.62
# Class name --> bottle
# Speed: 1.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 12.0ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.86
# Class name --> bottle
# Speed: 1.0ms preprocess, 12.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 12.0ms
# Confidence ---> 0.93
# Class name --> bottle
# Confidence ---> 0.89
# Class name --> person
# Speed: 2.6ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 12.0ms
# Confidence ---> 0.9
# Class name --> bottle
# Confidence ---> 0.88
# Class name --> person
# Speed: 2.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 11.4ms
# Confidence ---> 0.92
# Class name --> bottle
# Confidence ---> 0.89
# Class name --> person
# Speed: 2.1ms preprocess, 11.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 14.5ms
# Confidence ---> 0.94
# Class name --> bottle
# Confidence ---> 0.87
# Class name --> person
# Speed: 2.0ms preprocess, 14.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 12.0ms
# Confidence ---> 0.94
# Class name --> bottle
# Confidence ---> 0.87
# Class name --> person
# ...
# Confidence ---> 0.32
# Class name --> tvmonitor
# Confidence ---> 0.28
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 22.0ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.43
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 22.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 22.0ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.52
# Class name --> tvmonitor
# Confidence ---> 0.36
# Class name --> tvmonitor
# Speed: 3.0ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 21.4ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.62
# Class name --> tvmonitor
# Confidence ---> 0.31
# Class name --> tvmonitor
# Speed: 4.0ms preprocess, 21.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 23.0ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.66
# Class name --> tvmonitor
# Speed: 3.0ms preprocess, 23.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 22.0ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.59
# Class name --> tvmonitor
# Confidence ---> 0.3
# Class name --> tvmonitor
# Speed: 5.5ms preprocess, 22.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 12.0ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.62
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 10.0ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.5
# Class name --> tvmonitor
# Confidence ---> 0.45
# Class name --> tvmonitor
# Speed: 1.0ms preprocess, 10.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 18.0ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.61
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 18.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 18.0ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.64
# Class name --> tvmonitor
# Speed: 3.0ms preprocess, 18.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 14.0ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.56
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 14.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 17.0ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.44
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 17.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 25.1ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.48
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 25.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 13.0ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.33
# Class name --> tvmonitor
# Confidence ---> 0.32
# Class name --> tvmonitor
# Speed: 4.0ms preprocess, 13.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 13.0ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.32
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 13.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 11.0ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.43
# Class name --> tvmonitor
# Speed: 5.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 16.4ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.52
# Class name --> tvmonitor
# Speed: 3.0ms preprocess, 16.4ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 22.0ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.4
# Class name --> tvmonitor
# Confidence ---> 0.27
# Class name --> tvmonitor
# Speed: 2.5ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 15.9ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.56
# Class name --> tvmonitor
# Speed: 2.3ms preprocess, 15.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 19.1ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.46
# Class name --> tvmonitor
# Confidence ---> 0.33
# Class name --> tvmonitor
# Speed: 4.0ms preprocess, 19.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 10.3ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.47
# Class name --> tvmonitor
# Speed: 1.5ms preprocess, 10.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 11.8ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.56
# Class name --> tvmonitor
# Confidence ---> 0.29
# Class name --> tvmonitor
# Speed: 2.6ms preprocess, 11.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 17.0ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.63
# Class name --> tvmonitor
# Confidence ---> 0.38
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 17.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 19.0ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.4
# Class name --> tvmonitor
# Speed: 4.0ms preprocess, 19.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 11.7ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.36
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 11.7ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 12.0ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.51
# Class name --> tvmonitor
# Speed: 3.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 18.0ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.5
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 18.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 16.0ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.53
# Class name --> tvmonitor
# Confidence ---> 0.29
# Class name --> tvmonitor
# Speed: 3.0ms preprocess, 16.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 20.0ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.43
# Class name --> tvmonitor
# Confidence ---> 0.33
# Class name --> tvmonitor
# Speed: 3.0ms preprocess, 20.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 16.5ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.58
# Class name --> tvmonitor
# Confidence ---> 0.27
# Class name --> tvmonitor
# Speed: 3.0ms preprocess, 16.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 13.5ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.38
# Class name --> tvmonitor
# Confidence ---> 0.32
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 13.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 11.0ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.47
# Class name --> tvmonitor
# Speed: 1.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 11.7ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.46
# Class name --> tvmonitor
# Confidence ---> 0.44
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 11.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 18.6ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.46
# Class name --> tvmonitor
# Confidence ---> 0.44
# Class name --> tvmonitor
# Speed: 3.4ms preprocess, 18.6ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 15.0ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.47
# Class name --> tvmonitor
# Confidence ---> 0.45
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 refrigerator, 13.0ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.49
# Class name --> tvmonitor
# Confidence ---> 0.28
# Class name --> refrigerator
# Confidence ---> 0.27
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 13.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 16.0ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.51
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 16.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 11.8ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.45
# Class name --> tvmonitor
# Confidence ---> 0.34
# Class name --> tvmonitor
# Speed: 1.0ms preprocess, 11.8ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 12.0ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.52
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 18.0ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.49
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 18.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 1 refrigerator, 17.0ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.51
# Class name --> tvmonitor
# Confidence ---> 0.27
# Class name --> refrigerator
# Speed: 3.0ms preprocess, 17.0ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 16.7ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.37
# Class name --> tvmonitor
# Confidence ---> 0.28
# Class name --> tvmonitor
# Speed: 3.1ms preprocess, 16.7ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 23.1ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.39
# Class name --> tvmonitor
# Speed: 5.6ms preprocess, 23.1ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 17.6ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.42
# Class name --> tvmonitor
# Confidence ---> 0.4
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 17.6ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 1 refrigerator, 16.0ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.37
# Class name --> tvmonitor
# Confidence ---> 0.33
# Class name --> refrigerator
# Confidence ---> 0.3
# Class name --> tvmonitor
# Speed: 4.0ms preprocess, 16.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 16.0ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.46
# Class name --> tvmonitor
# Confidence ---> 0.36
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 16.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 22.0ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.49
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 22.7ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.5
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 22.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 22.0ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.55
# Class name --> tvmonitor
# Confidence ---> 0.28
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 22.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 23.4ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.51
# Class name --> tvmonitor
# Confidence ---> 0.29
# Class name --> tvmonitor
# Speed: 1.0ms preprocess, 23.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 22.0ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.58
# Class name --> tvmonitor
# Speed: 3.0ms preprocess, 22.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 22.1ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.38
# Class name --> tvmonitor
# Speed: 3.0ms preprocess, 22.1ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 21.7ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.37
# Class name --> tvmonitor
# Speed: 3.8ms preprocess, 21.7ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 22.9ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 3.0ms preprocess, 22.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 22.0ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.42
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 26.0ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.33
# Class name --> tvmonitor
# Speed: 3.0ms preprocess, 26.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 21.8ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.29
# Class name --> tvmonitor
# Speed: 2.1ms preprocess, 21.8ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 9.0ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.33
# Class name --> tvmonitor
# Confidence ---> 0.31
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 9.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 17.5ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.44
# Class name --> tvmonitor
# Confidence ---> 0.37
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 17.5ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 11.0ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.45
# Class name --> tvmonitor
# Confidence ---> 0.31
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 10.0ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.34
# Class name --> tvmonitor
# Speed: 3.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 13.5ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.45
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 13.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 15.0ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.41
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 tvs, 12.0ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.45
# Class name --> tvmonitor
# Confidence ---> 0.29
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 11.0ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.4
# Class name --> tvmonitor
# Speed: 3.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 11.0ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.27
# Class name --> tvmonitor
# Speed: 1.0ms preprocess, 11.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
