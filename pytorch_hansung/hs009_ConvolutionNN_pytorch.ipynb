# %% [markdown]
# ## CNN
#
# ### 영상분류
#
# - 컴퓨터 비전 분야의 핵심 태스크
#
# #### 영상분류의 어려운 점
# - Semantic gap - 의미적 간극. 모델이 저수준 데이터를 조합해 고수준 의미를 추론하기 어려움
# - Viewpoint variation. 시점 변화. 객체가 카메라가 보는 시점에 따라 다르게 보이는 문제
# - Illumination - 조명변화. 동일한 객체라도 조명의 강도, 방향, 색온도 등에 따라 다르게 보이는 현상
# - Deformation - 변형. 객체가 행태적으로 변형될 때 생기는 문제. 전혀 이상한 모습으로 있을때 다르게 보임
# - Occlusion - 가림. 객체의 일부가 다른 물체에 의해 가려지는 현상
# - Background clutter - 배경혼잡. 객체와 구분되는 배경이 복잡하거나 비슷한 특징을 가지고 있어 분류를 방해
# - Intralass variation - 클래스 내부 변이. 같은 클래스 내에서도 개체별로 다양한 형태를 가지는 경우.
#
# #### Data-driven approach
# - 이미지와 라벨 데이터를 수집
# - 머신러닝을 사용해서 image classifier를 훈련
# - 테스트 이미지에 대해서 학습된 모델 성능 평가

# %% [markdown]
# ### Convolution 연산 = filtering 작업
# - 영상 내 필요한 정보만 통과시키고 원치 않는 정보를 걸러내는 작업
# - 신호처리나 딥러닝에서 두 함수의 결합을 표현하는 연산으로, 하나의 함수(주로 커널 또는 필터)가 다른 함수(입력 데이터)에 특정 패턴을 찾거나 변환하는 방식으로 작동. 딥러닝에서 Convolution은 주로 이미지 데이터에서 특정 특징(예: 엣지, 모양, 텍스처)을 추출하는 데 사용
#
#
#     <img src="https://raw.githubusercontent.com/hugoMGSung/study-pytorch/refs/heads/main/images/torch0016.png" width="600">
#
#
# #### 계속
# - Filter (혹은 kernel)라고 불리는 규정된 영역을 기반으로 연산 수해
# - Filter 계수에 따라 출력이 결정
#
#     $$ s(t)=(x∗w)(t)=∫x(a)w(t−a)da $$
#
#     - x(a): 입력 함수 (데이터)
#     - w(t−a): 커널(필터) 함수
#     - s(t): 결과 값 (출력)

# %% [markdown]
# #### CNN
#
# <img src="https://raw.githubusercontent.com/hugoMGSung/study-pytorch/refs/heads/main/images/torch0017.png" width="800">
#
# - 사진이 입력되면 특징 추출. 새 이미지가 입력되면, 부리의 크기, 눈의 모양, 깃털 등 나누어서 파악 -> 컨볼루션
#     - 특징을 추출하는 패턴은 정사각형 모양 필터, 보통 3x3
# - 왼쪽 상단부터 오른쪽으로 이동하면서 각 위치마다 포개지는 숫자를 곱해서 모두 합산 -> 특성 맵(기록 결과)
#     - 핕터이 특성이 입력 사진 어느 부분에 많이 존재하는지 확인 가능
#     - 특성 맵의 위치의 값이 높으면 그 위치가 필터와 유사하다는 의미
#     - 신경망은 각 연결이 가중치를 학습하지만, CNN은 고정 연결이 없어 컨볼루션 과정으로 출력을 계산
#     - 사람이 아닌 모델 스스로 어느 특징이 좋은지 학습을 통해 필터를 생성
# - 필터의 개수만큼 생성된 특성 맵의 크기를 줄임 -> 맥스 풀링
#     - 가장 큰 값만 추출하여 출력을 작게 만드는 방법
# - 맥스풀링된 맵을 하나의 단위로 여러층으로 깊에 쌓아올림 -> 패턴담긴 특성 맵
#     - 낮은 층에서 단순한 패턴, 높은 층에서 복잡한 패턴을 추상화
# - 이 구조를 완전연결 신경망에 붙여 특성 맵을 사진의 클래스로 최종 분류
#
#
# ##### 전체 처리과정 구조도 1
#
# <img src="https://raw.githubusercontent.com/hugoMGSung/study-pytorch/refs/heads/main/images/torch0018.png" width="800">
#
#
# ##### 전체 처리과정 구조도 2
#
# <img src="https://raw.githubusercontent.com/hugoMGSung/study-pytorch/refs/heads/main/images/torch0019.png" width="800">

# %% [markdown]
# ### CNN 모델 실습
#
# #### CIFAR-19 dataset
# - 60,000 32x32 color images (50,000 training, 10,000 test)
# - 10 classes (airplane, automobile, bird, cat, deer, dog, frog, horse, ship, truck)

# %%
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
import torch.optim as optim
from torch.utils.data import DataLoader

import os
import matplotlib.pyplot as plt

# %% [markdown]
# ##### 분류 정확도 측정
#
# 1. output.topk:
#     - 모델의 예측 결과에서 상위 k개의 가장 높은 확률값을 가지는 클래스 인덱스를 추출
#     - 예를 들어, k=5라면, 각 샘플에 대해 상위 5개의 가장 높은 값과 해당 인덱스를 반환
#
# 2. correct:
#     - 모델의 예측 결과 pred와 실제 정답 target을 비교하여 일치하는 경우를 기록한 불린 배열
#
# 3. correct[:k].view(-1).float().sum():
#     - k개의 예측 중 실제로 정답과 일치한 개수를 계산
#
# 4. acc.append(correct_k.mul(1 / batch_size)):
#     - k개의 예측 중 맞은 개수를 배치 크기로 나누어 정확도를 계산

# %%
def accuracy(output, target, topk=(1,)):
    """
    모델의 예측 정확도를 top-k 기준으로 계산

    매개변수:
        output (torch.Tensor): 모델이 출력한 예측 값으로, 형태는 (배치 크기, 클래스 수)
        target (torch.Tensor): 정답 라벨, 형태는 (배치 크기)
        topk (tuple of int): 계산할 top-k 정확도의 기준을 지정 예) top-1,top-5.

    반환값:
        acc (list of torch.Tensor): 각 k에 대한 top-k 정확도를 저장한 리스트(퍼센트 값)
        num_cor (list of torch.Tensor): 각 k에 대해 맞춘 정답의 개수를 저장한 리스트
    """
    with torch.no_grad(): # 이 블록 안에서 기울기 계산을 비활성화(메모리 절약 및 계산 속도 개선)
        maxk = max(topk)  # top-k 중 가장 큰 k를 도출
        batch_size = target.size(0) ## 배치크기 가져오기

        # `output`에서 top-k에 해당하는 가장 높은 값을 가진 클래스 인덱스를 가져오기
        _, pred = output.topk(maxk, 1, True, True)  # `topk`는 (값, 인덱스)를 반환
        pred = pred.t()  # pred를 전치(transpose)하여 (k, batch_size) 형태로 변경

        # `pred`와 `target`을 비교하여 맞춘 결과를 기록
        correct = pred.eq(target.view(1, -1).expand_as(pred))

        acc = []        # 각 k에 대한 정확도를 저장할 리스트
        num_cor = []    # 각 k에 대해 맞춘 정답의 개수를 저장할 리스트

        # top-k의 각 k에 대해 정확도를 계산
        for k in topk:
            # `correct[:k]`에서 k개의 예측 중 맞은 개수를 확인
            correct_k = correct[:k].view(-1).float().sum(0, keepdim=True) # k개를 펼쳐서 합산
            num_cor.append(correct_k.clone())  # 맞춘 정답 개수를 저장
            acc.append(correct_k.mul(1/ batch_size))  # 정확도 계산 (정답 개수 / 배치 크기)

    return acc, num_cor  # 각 k에 대한 정확도와 정답 개수 반환

# %% [markdown]
# ##### 가중치 초기화 함수

# %%
def init_weights(m, init_type='normal', init_gain=0.02):
    """
    모델의 가중치를 초기화하는 함수.

    매개변수:
        m (nn.Module): 초기화할 레이어(모듈).
        init_type (str): 가중치 초기화 방식. ['normal', 'xavier', 'kaiming', 'orthogonal'] 중 선택.
        init_gain (float): 초기화 시 사용할 scaling factor (xavier, normal, orthogonal에서 사용).

    설명:
        이 함수는 주어진 레이어의 가중치를 초기화. Conv 또는 Linear 레이어는 가중치를
        지정된 방식에 따라 초기화하고, BatchNorm2d 레이어는 별도의 방식으로 초기화.
    """

    classname = m.__class__.__name__  # 현재 레이어의 클래스 이름 체크

    # Conv 또는 Linear 레이어인지 확인 (weight 속성이 있는 경우)
    if hasattr(m, 'weight') and (classname.find('Conv') != -1 or classname.find('Linear') != -1):
        # 초기화 유형에 따라 가중치를 초기화
        if init_type == 'normal':       # 정규분포 초기화
            nn.init.normal_(m.weight.data, 0.0, init_gain)
        elif init_type == 'xavier':     # Xavier 정규분포 초기화
            nn.init.xavier_normal_(m.weight.data, gain=init_gain)
        elif init_type == 'kaiming':    # Kaiming He 초기화 (ReLU 기반 네트워크에 적합)
            nn.init.kaiming_normal_(m.weight.data, a=0, mode='fan_in')
        elif init_type == 'orthogonal': # 직교 행렬 초기화
            nn.init.orthogonal_(m.weight.data, gain=init_gain)
        else: # 이외 유형 예외처리
            raise NotImplementedError(f'Initialization method "{init_type} is not implemented."')
        
        # 레이어에 bias가 존재하면 0으로 초기화
        if hasattr(m, 'bias') and m.bias is not None:
            nn.init.constant_(m.bias.data, 0.0)

    # BatchNorm2d 레이어일 경우 별도 초기화     
    elif classname.find('BatchNorm2d') != -1:
        # 가중치는 평균 1.0, 분산 init_gain인 정규분포로 초기화
        nn.init.normal_(m.weight.data, 1.0, init_gain)
        nn.init.constant_(m.bias.data, 0.0)  # 편향(bias)는 0(특정상수)으로 초기화

# %% [markdown]
# ##### CNN 클래스 정의

# %%
class Network(nn.Module):
    def __init__(self):
        super(Network, self).__init__()
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=32, kernel_size=(7,7), stride=(1,1))
        self.conv2 = nn.Conv2d(32, 64, (3,3), (1,1))
        self.conv3 = nn.Conv2d(64, 128, 3, 1)
        self.fc_code = nn.Linear(in_features=128, out_features=128)
        self.fc_output = nn.Linear(128, 10)
        self.relu = nn.ReLU(inplace=True)
        self.maxpool = nn.MaxPool2d(2)
        self.dropout = nn.Dropout(p=0.5)
        self.apply(init_weights)

    def forward(self, x):
        feature_map = self.conv1(x)
        activated = self.relu(feature_map)
        compressed = self.maxpool(activated)
        x = self.maxpool(self.relu(self.conv2(compressed)))
        x = self.maxpool(self.relu(self.conv3(x)))
        x = x.view(x.size(0), -1)
        code = self.dropout(self.relu(self.fc_code(x)))
        output = self.fc_output(code)
        return output, code

# %% [markdown]
# ##### 데이터셋 준비
#
# - torchvision.transforms - 데이터 증강을 위한 다양한 변환 제공
# - transforms.RandomHorizontalFlip() - 랜덤 좌우 반전
# - transforms.ToTensor() - 데이터를 Pytorch Tensor로 변환
# - transforms.Normalize() - 데이터 normalization 적용
# - num_workers - CPU -> GPU 데이터로드시 사용하는 코어개수

# %%
if not os.path.isdir('./ckpt'):
    os.makedirs('./ckpt')

if not os.path.isdir('./CIFAR_data'):
    os.makedirs('./CIFAR_data')

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)

train_transoform = transforms.Compose([transforms.RandomHorizontalFlip(), 
                                       transforms.ToTensor(), 
                                       transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2470, 0.2435, 0.2616))])
test_transoform = transforms.Compose([transforms.RandomHorizontalFlip(), 
                                       transforms.ToTensor(), 
                                       transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2470, 0.2435, 0.2616))])

trainset = torchvision.datasets.CIFAR10(root='./CIFAR_data', train=True, download=True, transform=train_transoform)
trainloader = DataLoader(trainset, batch_size=32, shuffle=True, num_workers=2)
testset = torchvision.datasets.CIFAR10(root='./CIFAR_data', train=False, download=True, transform=test_transoform)
testloader = DataLoader(testset, batch_size=32, shuffle=False, num_workers=2)
# Out:
# cuda
# Files already downloaded and verified
# Files already downloaded and verified

# %%
##### 모델, 옵티마이저, 손실함수
model = Network()
model.to(device)
params = model.parameters()
optimizer = optim.Adam(params, lr=1e-3, betas=(0.9, 0.999), weight_decay=0.001)
train_criterion = nn.CrossEntropyLoss(reduction='mean')

# %% [markdown]
# ##### CNN 모델 실습
#
# - 전체 처리에 40여분이 소요되므로 주의 필요

# %%
for epoch in range(1, 100):
    model.train()
    for step, (data, targets) in enumerate(trainloader):
        data = data.to(device, dtype=torch.float)
        targets = targets.to(device)

        optimizer.zero_grad()
        outputs, code = model(data)
        loss = nn.CrossEntropyLoss(reduction='mean')(outputs, targets)
        loss.backward()
        optimizer.step()
        loss = loss.item()
        acc, _ = accuracy(outputs, targets)
        acc = acc[0].item()

        if step % 10 == 0:
            print(f'Epoch {epoch} Step {step}/{len(trainloader)} Loss {loss:.4f} Accuracy {acc:.4f}')

    model.eval()
    total_cor = 0
    total_samples = 0

    with torch.no_grad():
        for step, (data, targets) in enumerate(testloader):
            data = data.to(device, dtype=torch.float)
            targets = targets.to(device)

            outputs, code = model(data)
            _, num_cor = accuracy(outputs, targets)
            num_cor = num_cor[0].item()

            total_samples += data.size(0)
            total_cor += num_cor
        
        acc = total_cor / total_samples
        print(f'Epoch {epoch} / Accuracy {acc:.4f}')

    path = f'./ckpt/model_state_{epoch}.st'
    torch.save(model.state_dict(), path)  ## 학습모델의 파라미터
# Out:
# Epoch 1 Step 0/1563 Loss 2.3025 Accuracy 0.1250
# Epoch 1 Step 10/1563 Loss 2.3026 Accuracy 0.0938
# Epoch 1 Step 20/1563 Loss 2.2815 Accuracy 0.1562
# Epoch 1 Step 30/1563 Loss 2.1492 Accuracy 0.1250
# Epoch 1 Step 40/1563 Loss 2.1574 Accuracy 0.1562
# Epoch 1 Step 50/1563 Loss 2.1982 Accuracy 0.0625
# Epoch 1 Step 60/1563 Loss 1.9314 Accuracy 0.3438
# Epoch 1 Step 70/1563 Loss 2.1989 Accuracy 0.1562
# Epoch 1 Step 80/1563 Loss 2.1263 Accuracy 0.0938
# Epoch 1 Step 90/1563 Loss 2.2638 Accuracy 0.2188
# Epoch 1 Step 100/1563 Loss 1.9816 Accuracy 0.2812
# Epoch 1 Step 110/1563 Loss 2.3404 Accuracy 0.1562
# Epoch 1 Step 120/1563 Loss 2.2318 Accuracy 0.0625
# Epoch 1 Step 130/1563 Loss 2.1506 Accuracy 0.1875
# Epoch 1 Step 140/1563 Loss 2.1759 Accuracy 0.1250
# Epoch 1 Step 150/1563 Loss 1.9630 Accuracy 0.1875
# Epoch 1 Step 160/1563 Loss 2.0435 Accuracy 0.2188
# Epoch 1 Step 170/1563 Loss 2.0130 Accuracy 0.1875
# Epoch 1 Step 180/1563 Loss 2.0889 Accuracy 0.3438
# Epoch 1 Step 190/1563 Loss 1.9342 Accuracy 0.1250
# Epoch 1 Step 200/1563 Loss 2.2018 Accuracy 0.0312
# Epoch 1 Step 210/1563 Loss 1.9366 Accuracy 0.2500
# Epoch 1 Step 220/1563 Loss 2.0825 Accuracy 0.1562
# Epoch 1 Step 230/1563 Loss 2.0884 Accuracy 0.1250
# Epoch 1 Step 240/1563 Loss 2.0382 Accuracy 0.1562
# Epoch 1 Step 250/1563 Loss 1.9701 Accuracy 0.2188
# Epoch 1 Step 260/1563 Loss 1.8714 Accuracy 0.1875
# Epoch 1 Step 270/1563 Loss 2.1207 Accuracy 0.0625
# Epoch 1 Step 280/1563 Loss 1.8522 Accuracy 0.2188
# Epoch 1 Step 290/1563 Loss 1.9878 Accuracy 0.1875
# Epoch 1 Step 300/1563 Loss 1.9851 Accuracy 0.2812
# Epoch 1 Step 310/1563 Loss 2.1658 Accuracy 0.1875
# Epoch 1 Step 320/1563 Loss 2.0099 Accuracy 0.1250
# Epoch 1 Step 330/1563 Loss 1.8638 Accuracy 0.2500
# Epoch 1 Step 340/1563 Loss 1.9455 Accuracy 0.1875
# Epoch 1 Step 350/1563 Loss 1.9536 Accuracy 0.2812
# Epoch 1 Step 360/1563 Loss 1.9361 Accuracy 0.3125
# Epoch 1 Step 370/1563 Loss 1.9237 Accuracy 0.1875
# Epoch 1 Step 380/1563 Loss 1.8915 Accuracy 0.2500
# Epoch 1 Step 390/1563 Loss 2.0002 Accuracy 0.2188
# Epoch 1 Step 400/1563 Loss 1.7879 Accuracy 0.3125
# Epoch 1 Step 410/1563 Loss 2.1366 Accuracy 0.1250
# Epoch 1 Step 420/1563 Loss 1.8696 Accuracy 0.3438
# Epoch 1 Step 430/1563 Loss 1.7687 Accuracy 0.3438
# Epoch 1 Step 440/1563 Loss 1.9384 Accuracy 0.1875
# Epoch 1 Step 450/1563 Loss 1.7452 Accuracy 0.2500
# Epoch 1 Step 460/1563 Loss 1.8732 Accuracy 0.2812
# Epoch 1 Step 470/1563 Loss 1.9013 Accuracy 0.1250
# Epoch 1 Step 480/1563 Loss 1.7494 Accuracy 0.4062
# Epoch 1 Step 490/1563 Loss 1.8940 Accuracy 0.1250
# Epoch 1 Step 500/1563 Loss 1.9464 Accuracy 0.2188
# Epoch 1 Step 510/1563 Loss 1.8766 Accuracy 0.2812
# Epoch 1 Step 520/1563 Loss 1.8054 Accuracy 0.2812
# Epoch 1 Step 530/1563 Loss 1.9658 Accuracy 0.2188
# Epoch 1 Step 540/1563 Loss 2.0140 Accuracy 0.2188
# Epoch 1 Step 550/1563 Loss 1.8564 Accuracy 0.2812
# Epoch 1 Step 560/1563 Loss 1.7303 Accuracy 0.2812
# Epoch 1 Step 570/1563 Loss 1.7976 Accuracy 0.4688
# Epoch 1 Step 580/1563 Loss 1.9624 Accuracy 0.2188
# Epoch 1 Step 590/1563 Loss 1.8310 Accuracy 0.2812
# Epoch 1 Step 600/1563 Loss 1.8455 Accuracy 0.3438
# Epoch 1 Step 610/1563 Loss 1.8917 Accuracy 0.2188
# Epoch 1 Step 620/1563 Loss 1.6580 Accuracy 0.3750
# Epoch 1 Step 630/1563 Loss 1.6191 Accuracy 0.3750
# Epoch 1 Step 640/1563 Loss 1.8269 Accuracy 0.2500
# Epoch 1 Step 650/1563 Loss 1.7877 Accuracy 0.3438
# Epoch 1 Step 660/1563 Loss 2.1073 Accuracy 0.3125
# Epoch 1 Step 670/1563 Loss 2.0209 Accuracy 0.2500
# Epoch 1 Step 680/1563 Loss 1.8641 Accuracy 0.3750
# Epoch 1 Step 690/1563 Loss 1.6554 Accuracy 0.4062
# Epoch 1 Step 700/1563 Loss 1.6535 Accuracy 0.4375
# Epoch 1 Step 710/1563 Loss 1.7326 Accuracy 0.2812
# Epoch 1 Step 720/1563 Loss 1.8664 Accuracy 0.4375
# Epoch 1 Step 730/1563 Loss 1.9747 Accuracy 0.3438
# Epoch 1 Step 740/1563 Loss 1.7283 Accuracy 0.3438
# Epoch 1 Step 750/1563 Loss 2.0103 Accuracy 0.1875
# Epoch 1 Step 760/1563 Loss 1.7471 Accuracy 0.4062
# Epoch 1 Step 770/1563 Loss 1.5944 Accuracy 0.5000
# Epoch 1 Step 780/1563 Loss 1.8347 Accuracy 0.3438
# Epoch 1 Step 790/1563 Loss 2.3204 Accuracy 0.2188
# Epoch 1 Step 800/1563 Loss 2.0085 Accuracy 0.3125
# Epoch 1 Step 810/1563 Loss 1.9832 Accuracy 0.3438
# Epoch 1 Step 820/1563 Loss 1.5972 Accuracy 0.3125
# Epoch 1 Step 830/1563 Loss 1.7163 Accuracy 0.3750
# Epoch 1 Step 840/1563 Loss 1.6006 Accuracy 0.5000
# Epoch 1 Step 850/1563 Loss 1.6530 Accuracy 0.3438
# Epoch 1 Step 860/1563 Loss 1.7011 Accuracy 0.4375
# Epoch 1 Step 870/1563 Loss 2.0121 Accuracy 0.3125
# Epoch 1 Step 880/1563 Loss 1.5478 Accuracy 0.4688
# Epoch 1 Step 890/1563 Loss 1.6949 Accuracy 0.3125
# Epoch 1 Step 900/1563 Loss 1.8379 Accuracy 0.3125
# Epoch 1 Step 910/1563 Loss 1.7662 Accuracy 0.3750
# Epoch 1 Step 920/1563 Loss 1.6981 Accuracy 0.4062
# Epoch 1 Step 930/1563 Loss 1.6557 Accuracy 0.2812
# Epoch 1 Step 940/1563 Loss 1.9156 Accuracy 0.3750
# Epoch 1 Step 950/1563 Loss 1.7265 Accuracy 0.4375
# Epoch 1 Step 960/1563 Loss 1.3706 Accuracy 0.5625
# Epoch 1 Step 970/1563 Loss 1.8758 Accuracy 0.4062
# Epoch 1 Step 980/1563 Loss 1.4275 Accuracy 0.4688
# Epoch 1 Step 990/1563 Loss 1.8812 Accuracy 0.2812
# Epoch 1 Step 1000/1563 Loss 1.9245 Accuracy 0.2188
# Epoch 1 Step 1010/1563 Loss 1.8039 Accuracy 0.3125
# Epoch 1 Step 1020/1563 Loss 1.7490 Accuracy 0.3750
# Epoch 1 Step 1030/1563 Loss 1.7482 Accuracy 0.3750
# Epoch 1 Step 1040/1563 Loss 1.4958 Accuracy 0.3750
# Epoch 1 Step 1050/1563 Loss 1.6991 Accuracy 0.4375
# Epoch 1 Step 1060/1563 Loss 1.5345 Accuracy 0.3750
# Epoch 1 Step 1070/1563 Loss 1.8652 Accuracy 0.3438
# Epoch 1 Step 1080/1563 Loss 1.9035 Accuracy 0.2500
# Epoch 1 Step 1090/1563 Loss 1.7161 Accuracy 0.4375
# Epoch 1 Step 1100/1563 Loss 1.7921 Accuracy 0.4375
# Epoch 1 Step 1110/1563 Loss 2.0567 Accuracy 0.1875
# Epoch 1 Step 1120/1563 Loss 1.9125 Accuracy 0.2812
# Epoch 1 Step 1130/1563 Loss 1.7524 Accuracy 0.4375
# Epoch 1 Step 1140/1563 Loss 1.7269 Accuracy 0.4062
# Epoch 1 Step 1150/1563 Loss 1.6658 Accuracy 0.2812
# Epoch 1 Step 1160/1563 Loss 1.7225 Accuracy 0.4375
# Epoch 1 Step 1170/1563 Loss 1.7857 Accuracy 0.2812
# Epoch 1 Step 1180/1563 Loss 1.4739 Accuracy 0.4062
# Epoch 1 Step 1190/1563 Loss 1.5236 Accuracy 0.5938
# Epoch 1 Step 1200/1563 Loss 1.3791 Accuracy 0.4688
# Epoch 1 Step 1210/1563 Loss 1.5087 Accuracy 0.4062
# Epoch 1 Step 1220/1563 Loss 1.5304 Accuracy 0.4375
# Epoch 1 Step 1230/1563 Loss 1.9460 Accuracy 0.2500
# Epoch 1 Step 1240/1563 Loss 1.6660 Accuracy 0.3438
# Epoch 1 Step 1250/1563 Loss 1.5186 Accuracy 0.3750
# Epoch 1 Step 1260/1563 Loss 1.5819 Accuracy 0.4062
# Epoch 1 Step 1270/1563 Loss 1.4234 Accuracy 0.5938
# Epoch 1 Step 1280/1563 Loss 1.6654 Accuracy 0.2500
# Epoch 1 Step 1290/1563 Loss 1.5254 Accuracy 0.4375
# Epoch 1 Step 1300/1563 Loss 1.6352 Accuracy 0.4688
# Epoch 1 Step 1310/1563 Loss 1.5137 Accuracy 0.2812
# Epoch 1 Step 1320/1563 Loss 1.4513 Accuracy 0.4688
# Epoch 1 Step 1330/1563 Loss 1.2782 Accuracy 0.6562
# Epoch 1 Step 1340/1563 Loss 1.7073 Accuracy 0.2812
# Epoch 1 Step 1350/1563 Loss 2.1296 Accuracy 0.2812
# Epoch 1 Step 1360/1563 Loss 1.6212 Accuracy 0.4062
# Epoch 1 Step 1370/1563 Loss 1.6237 Accuracy 0.3750
# Epoch 1 Step 1380/1563 Loss 1.5833 Accuracy 0.4062
# Epoch 1 Step 1390/1563 Loss 1.5789 Accuracy 0.4375
# Epoch 1 Step 1400/1563 Loss 1.7347 Accuracy 0.3438
# Epoch 1 Step 1410/1563 Loss 1.7449 Accuracy 0.3750
# Epoch 1 Step 1420/1563 Loss 1.4796 Accuracy 0.5000
# Epoch 1 Step 1430/1563 Loss 1.5245 Accuracy 0.4375
# Epoch 1 Step 1440/1563 Loss 1.8056 Accuracy 0.2812
# Epoch 1 Step 1450/1563 Loss 1.6490 Accuracy 0.4375
# Epoch 1 Step 1460/1563 Loss 1.5989 Accuracy 0.5000
# Epoch 1 Step 1470/1563 Loss 1.6610 Accuracy 0.2812
# Epoch 1 Step 1480/1563 Loss 1.4534 Accuracy 0.4062
# Epoch 1 Step 1490/1563 Loss 1.5220 Accuracy 0.3750
# Epoch 1 Step 1500/1563 Loss 1.4822 Accuracy 0.4375
# Epoch 1 Step 1510/1563 Loss 1.5975 Accuracy 0.4375
# Epoch 1 Step 1520/1563 Loss 1.6090 Accuracy 0.4375
# Epoch 1 Step 1530/1563 Loss 1.5822 Accuracy 0.3750
# Epoch 1 Step 1540/1563 Loss 1.4567 Accuracy 0.4062
# Epoch 1 Step 1550/1563 Loss 1.5868 Accuracy 0.3125
# Epoch 1 Step 1560/1563 Loss 1.6737 Accuracy 0.3125
# Epoch 1 / Accuracy 0.4444
# Epoch 2 Step 0/1563 Loss 1.2610 Accuracy 0.5625
# Epoch 2 Step 10/1563 Loss 1.5901 Accuracy 0.3750
# Epoch 2 Step 20/1563 Loss 1.8490 Accuracy 0.4062
# Epoch 2 Step 30/1563 Loss 1.8202 Accuracy 0.4688
# Epoch 2 Step 40/1563 Loss 1.3954 Accuracy 0.5312
# Epoch 2 Step 50/1563 Loss 2.0546 Accuracy 0.3438
# Epoch 2 Step 60/1563 Loss 1.6796 Accuracy 0.4375
# Epoch 2 Step 70/1563 Loss 1.4557 Accuracy 0.4375
# Epoch 2 Step 80/1563 Loss 1.5285 Accuracy 0.4062
# Epoch 2 Step 90/1563 Loss 1.4866 Accuracy 0.4062
# Epoch 2 Step 100/1563 Loss 1.2796 Accuracy 0.5312
# Epoch 2 Step 110/1563 Loss 2.1937 Accuracy 0.2188
# Epoch 2 Step 120/1563 Loss 2.0334 Accuracy 0.4062
# Epoch 2 Step 130/1563 Loss 1.6064 Accuracy 0.3438
# Epoch 2 Step 140/1563 Loss 1.7546 Accuracy 0.3750
# Epoch 2 Step 150/1563 Loss 1.5726 Accuracy 0.3438
# Epoch 2 Step 160/1563 Loss 1.2871 Accuracy 0.5000
# Epoch 2 Step 170/1563 Loss 1.2618 Accuracy 0.5312
# Epoch 2 Step 180/1563 Loss 1.6531 Accuracy 0.3125
# Epoch 2 Step 190/1563 Loss 1.5191 Accuracy 0.4375
# Epoch 2 Step 200/1563 Loss 1.4073 Accuracy 0.4375
# Epoch 2 Step 210/1563 Loss 1.6396 Accuracy 0.4062
# Epoch 2 Step 220/1563 Loss 1.9272 Accuracy 0.3438
# Epoch 2 Step 230/1563 Loss 1.4741 Accuracy 0.4062
# Epoch 2 Step 240/1563 Loss 1.5820 Accuracy 0.4375
# Epoch 2 Step 250/1563 Loss 1.4372 Accuracy 0.5938
# Epoch 2 Step 260/1563 Loss 1.2228 Accuracy 0.5938
# Epoch 2 Step 270/1563 Loss 1.8044 Accuracy 0.4062
# Epoch 2 Step 280/1563 Loss 1.6918 Accuracy 0.4062
# Epoch 2 Step 290/1563 Loss 1.2735 Accuracy 0.4688
# Epoch 2 Step 300/1563 Loss 1.4711 Accuracy 0.4688
# Epoch 2 Step 310/1563 Loss 1.7012 Accuracy 0.5312
# Epoch 2 Step 320/1563 Loss 1.6555 Accuracy 0.4688
# Epoch 2 Step 330/1563 Loss 1.5152 Accuracy 0.4375
# Epoch 2 Step 340/1563 Loss 1.6809 Accuracy 0.4688
# Epoch 2 Step 350/1563 Loss 1.8693 Accuracy 0.3125
# Epoch 2 Step 360/1563 Loss 1.3877 Accuracy 0.6250
# Epoch 2 Step 370/1563 Loss 1.4371 Accuracy 0.4375
# Epoch 2 Step 380/1563 Loss 1.4980 Accuracy 0.5312
# Epoch 2 Step 390/1563 Loss 1.3681 Accuracy 0.5312
# Epoch 2 Step 400/1563 Loss 1.3381 Accuracy 0.4688
# Epoch 2 Step 410/1563 Loss 1.4585 Accuracy 0.5000
# Epoch 2 Step 420/1563 Loss 1.4884 Accuracy 0.4688
# Epoch 2 Step 430/1563 Loss 1.7435 Accuracy 0.4688
# Epoch 2 Step 440/1563 Loss 1.6783 Accuracy 0.4375
# Epoch 2 Step 450/1563 Loss 1.9566 Accuracy 0.4375
# Epoch 2 Step 460/1563 Loss 1.8046 Accuracy 0.3125
# Epoch 2 Step 470/1563 Loss 1.4813 Accuracy 0.4062
# Epoch 2 Step 480/1563 Loss 1.4469 Accuracy 0.5000
# Epoch 2 Step 490/1563 Loss 1.6353 Accuracy 0.5000
# Epoch 2 Step 500/1563 Loss 1.8183 Accuracy 0.4062
# Epoch 2 Step 510/1563 Loss 2.0759 Accuracy 0.2188
# Epoch 2 Step 520/1563 Loss 1.4786 Accuracy 0.5000
# Epoch 2 Step 530/1563 Loss 1.3349 Accuracy 0.4688
# Epoch 2 Step 540/1563 Loss 1.3854 Accuracy 0.5000
# Epoch 2 Step 550/1563 Loss 1.3640 Accuracy 0.4062
# Epoch 2 Step 560/1563 Loss 1.8123 Accuracy 0.3750
# Epoch 2 Step 570/1563 Loss 1.4561 Accuracy 0.5625
# Epoch 2 Step 580/1563 Loss 1.7619 Accuracy 0.3750
# Epoch 2 Step 590/1563 Loss 1.4432 Accuracy 0.5000
# Epoch 2 Step 600/1563 Loss 1.4218 Accuracy 0.4375
# Epoch 2 Step 610/1563 Loss 1.5788 Accuracy 0.3750
# Epoch 2 Step 620/1563 Loss 1.5357 Accuracy 0.4062
# Epoch 2 Step 630/1563 Loss 1.3967 Accuracy 0.4688
# Epoch 2 Step 640/1563 Loss 1.6322 Accuracy 0.3125
# Epoch 2 Step 650/1563 Loss 1.3555 Accuracy 0.5312
# Epoch 2 Step 660/1563 Loss 1.2811 Accuracy 0.5938
# Epoch 2 Step 670/1563 Loss 1.4903 Accuracy 0.4688
# Epoch 2 Step 680/1563 Loss 1.6708 Accuracy 0.2812
# Epoch 2 Step 690/1563 Loss 1.4745 Accuracy 0.4062
# Epoch 2 Step 700/1563 Loss 1.1619 Accuracy 0.5000
# Epoch 2 Step 710/1563 Loss 1.9485 Accuracy 0.3750
# Epoch 2 Step 720/1563 Loss 1.1991 Accuracy 0.6250
# Epoch 2 Step 730/1563 Loss 1.2911 Accuracy 0.4375
# Epoch 2 Step 740/1563 Loss 1.3418 Accuracy 0.5938
# Epoch 2 Step 750/1563 Loss 1.8958 Accuracy 0.3750
# Epoch 2 Step 760/1563 Loss 1.3813 Accuracy 0.5000
# Epoch 2 Step 770/1563 Loss 1.3370 Accuracy 0.6250
# Epoch 2 Step 780/1563 Loss 1.2841 Accuracy 0.5312
# Epoch 2 Step 790/1563 Loss 1.5231 Accuracy 0.4375
# Epoch 2 Step 800/1563 Loss 1.9067 Accuracy 0.3125
# Epoch 2 Step 810/1563 Loss 1.7963 Accuracy 0.2812
# Epoch 2 Step 820/1563 Loss 1.6300 Accuracy 0.4375
# Epoch 2 Step 830/1563 Loss 1.6562 Accuracy 0.6250
# Epoch 2 Step 840/1563 Loss 1.4931 Accuracy 0.5938
# Epoch 2 Step 850/1563 Loss 1.2603 Accuracy 0.5625
# Epoch 2 Step 860/1563 Loss 1.3342 Accuracy 0.5938
# Epoch 2 Step 870/1563 Loss 1.1791 Accuracy 0.5625
# Epoch 2 Step 880/1563 Loss 1.5970 Accuracy 0.4688
# Epoch 2 Step 890/1563 Loss 1.4726 Accuracy 0.3438
# Epoch 2 Step 900/1563 Loss 1.7598 Accuracy 0.4375
# Epoch 2 Step 910/1563 Loss 1.5656 Accuracy 0.4375
# Epoch 2 Step 920/1563 Loss 1.8072 Accuracy 0.4062
# Epoch 2 Step 930/1563 Loss 1.4491 Accuracy 0.5000
# Epoch 2 Step 940/1563 Loss 1.2697 Accuracy 0.5000
# Epoch 2 Step 950/1563 Loss 1.6619 Accuracy 0.5312
# Epoch 2 Step 960/1563 Loss 1.0430 Accuracy 0.6250
# Epoch 2 Step 970/1563 Loss 1.2988 Accuracy 0.5625
# Epoch 2 Step 980/1563 Loss 1.3370 Accuracy 0.5625
# Epoch 2 Step 990/1563 Loss 1.7881 Accuracy 0.4062
# Epoch 2 Step 1000/1563 Loss 1.5972 Accuracy 0.3438
# Epoch 2 Step 1010/1563 Loss 1.1283 Accuracy 0.5625
# Epoch 2 Step 1020/1563 Loss 1.6195 Accuracy 0.4062
# Epoch 2 Step 1030/1563 Loss 1.6778 Accuracy 0.4062
# Epoch 2 Step 1040/1563 Loss 1.6855 Accuracy 0.3750
# Epoch 2 Step 1050/1563 Loss 1.4631 Accuracy 0.5625
# Epoch 2 Step 1060/1563 Loss 1.4784 Accuracy 0.4062
# Epoch 2 Step 1070/1563 Loss 1.6684 Accuracy 0.4688
# Epoch 2 Step 1080/1563 Loss 1.4707 Accuracy 0.5312
# Epoch 2 Step 1090/1563 Loss 1.4909 Accuracy 0.3750
# Epoch 2 Step 1100/1563 Loss 1.3030 Accuracy 0.6875
# Epoch 2 Step 1110/1563 Loss 1.8162 Accuracy 0.3750
# Epoch 2 Step 1120/1563 Loss 1.3815 Accuracy 0.5625
# Epoch 2 Step 1130/1563 Loss 1.9512 Accuracy 0.2812
# Epoch 2 Step 1140/1563 Loss 1.4094 Accuracy 0.4062
# Epoch 2 Step 1150/1563 Loss 1.6243 Accuracy 0.3750
# Epoch 2 Step 1160/1563 Loss 1.3421 Accuracy 0.4688
# Epoch 2 Step 1170/1563 Loss 1.5597 Accuracy 0.3438
# Epoch 2 Step 1180/1563 Loss 1.6279 Accuracy 0.2812
# Epoch 2 Step 1190/1563 Loss 1.2610 Accuracy 0.5938
# Epoch 2 Step 1200/1563 Loss 1.4512 Accuracy 0.5000
# Epoch 2 Step 1210/1563 Loss 1.6821 Accuracy 0.4062
# Epoch 2 Step 1220/1563 Loss 1.4403 Accuracy 0.4688
# Epoch 2 Step 1230/1563 Loss 1.3741 Accuracy 0.5625
# Epoch 2 Step 1240/1563 Loss 1.3252 Accuracy 0.4375
# Epoch 2 Step 1250/1563 Loss 1.1502 Accuracy 0.5625
# Epoch 2 Step 1260/1563 Loss 1.4172 Accuracy 0.5312
# Epoch 2 Step 1270/1563 Loss 1.3055 Accuracy 0.5312
# Epoch 2 Step 1280/1563 Loss 1.1714 Accuracy 0.5625
# Epoch 2 Step 1290/1563 Loss 1.4785 Accuracy 0.4375
# Epoch 2 Step 1300/1563 Loss 1.2376 Accuracy 0.5625
# Epoch 2 Step 1310/1563 Loss 1.6789 Accuracy 0.3438
# Epoch 2 Step 1320/1563 Loss 1.2770 Accuracy 0.4375
# Epoch 2 Step 1330/1563 Loss 1.2174 Accuracy 0.5938
# Epoch 2 Step 1340/1563 Loss 1.3829 Accuracy 0.5312
# Epoch 2 Step 1350/1563 Loss 1.3946 Accuracy 0.5312
# Epoch 2 Step 1360/1563 Loss 1.3815 Accuracy 0.5312
# Epoch 2 Step 1370/1563 Loss 1.2747 Accuracy 0.5938
# Epoch 2 Step 1380/1563 Loss 1.9003 Accuracy 0.4688
# Epoch 2 Step 1390/1563 Loss 1.7434 Accuracy 0.4688
# Epoch 2 Step 1400/1563 Loss 1.5010 Accuracy 0.4688
# Epoch 2 Step 1410/1563 Loss 1.2318 Accuracy 0.5312
# Epoch 2 Step 1420/1563 Loss 1.3683 Accuracy 0.5000
# Epoch 2 Step 1430/1563 Loss 1.5883 Accuracy 0.4375
# Epoch 2 Step 1440/1563 Loss 1.2842 Accuracy 0.5000
# Epoch 2 Step 1450/1563 Loss 1.6538 Accuracy 0.4062
# Epoch 2 Step 1460/1563 Loss 1.8073 Accuracy 0.3125
# Epoch 2 Step 1470/1563 Loss 1.4131 Accuracy 0.3125
# Epoch 2 Step 1480/1563 Loss 1.3182 Accuracy 0.5312
# Epoch 2 Step 1490/1563 Loss 1.2188 Accuracy 0.5938
# Epoch 2 Step 1500/1563 Loss 1.5437 Accuracy 0.4688
# Epoch 2 Step 1510/1563 Loss 1.6310 Accuracy 0.4062
# Epoch 2 Step 1520/1563 Loss 1.0799 Accuracy 0.5625
# Epoch 2 Step 1530/1563 Loss 1.4178 Accuracy 0.4375
# Epoch 2 Step 1540/1563 Loss 1.6974 Accuracy 0.3438
# Epoch 2 Step 1550/1563 Loss 1.8591 Accuracy 0.3750
# Epoch 2 Step 1560/1563 Loss 1.4068 Accuracy 0.5938
# Epoch 2 / Accuracy 0.4931
# Epoch 3 Step 0/1563 Loss 1.6566 Accuracy 0.3438
# Epoch 3 Step 10/1563 Loss 1.5735 Accuracy 0.4688
# Epoch 3 Step 20/1563 Loss 1.4312 Accuracy 0.5625
# Epoch 3 Step 30/1563 Loss 1.6241 Accuracy 0.4062
# Epoch 3 Step 40/1563 Loss 1.2814 Accuracy 0.5000
# Epoch 3 Step 50/1563 Loss 1.4752 Accuracy 0.4375
# Epoch 3 Step 60/1563 Loss 1.0722 Accuracy 0.5938
# Epoch 3 Step 70/1563 Loss 1.4385 Accuracy 0.4375
# Epoch 3 Step 80/1563 Loss 1.3160 Accuracy 0.5312
# Epoch 3 Step 90/1563 Loss 1.2091 Accuracy 0.5938
# Epoch 3 Step 100/1563 Loss 1.5435 Accuracy 0.4375
# Epoch 3 Step 110/1563 Loss 1.4688 Accuracy 0.4375
# Epoch 3 Step 120/1563 Loss 1.4942 Accuracy 0.4688
# Epoch 3 Step 130/1563 Loss 1.3580 Accuracy 0.4375
# Epoch 3 Step 140/1563 Loss 1.3522 Accuracy 0.5000
# Epoch 3 Step 150/1563 Loss 1.5229 Accuracy 0.4688
# Epoch 3 Step 160/1563 Loss 1.7481 Accuracy 0.3438
# Epoch 3 Step 170/1563 Loss 1.1367 Accuracy 0.5938
# Epoch 3 Step 180/1563 Loss 1.4959 Accuracy 0.5312
# Epoch 3 Step 190/1563 Loss 1.4997 Accuracy 0.2812
# Epoch 3 Step 200/1563 Loss 1.3336 Accuracy 0.5625
# Epoch 3 Step 210/1563 Loss 0.9998 Accuracy 0.8125
# Epoch 3 Step 220/1563 Loss 1.6104 Accuracy 0.5625
# Epoch 3 Step 230/1563 Loss 1.2017 Accuracy 0.6250
# Epoch 3 Step 240/1563 Loss 1.4180 Accuracy 0.5000
# Epoch 3 Step 250/1563 Loss 1.3021 Accuracy 0.5312
# Epoch 3 Step 260/1563 Loss 1.1324 Accuracy 0.5938
# Epoch 3 Step 270/1563 Loss 1.6859 Accuracy 0.3438
# Epoch 3 Step 280/1563 Loss 1.1964 Accuracy 0.5938
# Epoch 3 Step 290/1563 Loss 1.3827 Accuracy 0.4688
# Epoch 3 Step 300/1563 Loss 1.3916 Accuracy 0.5312
# Epoch 3 Step 310/1563 Loss 1.3787 Accuracy 0.5625
# Epoch 3 Step 320/1563 Loss 1.5194 Accuracy 0.3750
# Epoch 3 Step 330/1563 Loss 1.2266 Accuracy 0.6250
# Epoch 3 Step 340/1563 Loss 1.4262 Accuracy 0.5000
# Epoch 3 Step 350/1563 Loss 1.0008 Accuracy 0.6562
# Epoch 3 Step 360/1563 Loss 1.4907 Accuracy 0.4062
# Epoch 3 Step 370/1563 Loss 1.5052 Accuracy 0.5625
# Epoch 3 Step 380/1563 Loss 1.5305 Accuracy 0.4062
# Epoch 3 Step 390/1563 Loss 1.6967 Accuracy 0.3750
# Epoch 3 Step 400/1563 Loss 1.3372 Accuracy 0.5000
# Epoch 3 Step 410/1563 Loss 1.1699 Accuracy 0.6250
# Epoch 3 Step 420/1563 Loss 1.6394 Accuracy 0.4062
# Epoch 3 Step 430/1563 Loss 1.4754 Accuracy 0.5000
# Epoch 3 Step 440/1563 Loss 1.5191 Accuracy 0.5625
# Epoch 3 Step 450/1563 Loss 1.3981 Accuracy 0.4375
# Epoch 3 Step 460/1563 Loss 1.2356 Accuracy 0.5312
# Epoch 3 Step 470/1563 Loss 1.2424 Accuracy 0.5625
# Epoch 3 Step 480/1563 Loss 1.5491 Accuracy 0.3750
# Epoch 3 Step 490/1563 Loss 1.1340 Accuracy 0.5625
# Epoch 3 Step 500/1563 Loss 1.1415 Accuracy 0.6875
# Epoch 3 Step 510/1563 Loss 1.5543 Accuracy 0.4688
# Epoch 3 Step 520/1563 Loss 1.3680 Accuracy 0.4375
# Epoch 3 Step 530/1563 Loss 1.6921 Accuracy 0.3438
# Epoch 3 Step 540/1563 Loss 1.4345 Accuracy 0.5000
# Epoch 3 Step 550/1563 Loss 1.1848 Accuracy 0.5938
# Epoch 3 Step 560/1563 Loss 1.1547 Accuracy 0.5312
# Epoch 3 Step 570/1563 Loss 1.3909 Accuracy 0.5625
# Epoch 3 Step 580/1563 Loss 1.2638 Accuracy 0.4688
# Epoch 3 Step 590/1563 Loss 0.9491 Accuracy 0.6562
# Epoch 3 Step 600/1563 Loss 1.3302 Accuracy 0.4062
# Epoch 3 Step 610/1563 Loss 1.4309 Accuracy 0.4688
# Epoch 3 Step 620/1563 Loss 1.4836 Accuracy 0.3750
# Epoch 3 Step 630/1563 Loss 1.4132 Accuracy 0.5000
# Epoch 3 Step 640/1563 Loss 1.4075 Accuracy 0.4062
# Epoch 3 Step 650/1563 Loss 1.1448 Accuracy 0.5625
# Epoch 3 Step 660/1563 Loss 1.5170 Accuracy 0.3750
# Epoch 3 Step 670/1563 Loss 1.3045 Accuracy 0.4688
# Epoch 3 Step 680/1563 Loss 1.3009 Accuracy 0.5000
# Epoch 3 Step 690/1563 Loss 1.2891 Accuracy 0.5625
# Epoch 3 Step 700/1563 Loss 1.4622 Accuracy 0.4062
# Epoch 3 Step 710/1563 Loss 1.2537 Accuracy 0.5625
# Epoch 3 Step 720/1563 Loss 1.3057 Accuracy 0.5625
# Epoch 3 Step 730/1563 Loss 1.3523 Accuracy 0.5000
# Epoch 3 Step 740/1563 Loss 1.2575 Accuracy 0.5312
# Epoch 3 Step 750/1563 Loss 1.2115 Accuracy 0.6250
# Epoch 3 Step 760/1563 Loss 1.5490 Accuracy 0.5000
# Epoch 3 Step 770/1563 Loss 1.4930 Accuracy 0.5312
# Epoch 3 Step 780/1563 Loss 1.2732 Accuracy 0.5000
# Epoch 3 Step 790/1563 Loss 1.5046 Accuracy 0.5000
# Epoch 3 Step 800/1563 Loss 1.2876 Accuracy 0.5312
# Epoch 3 Step 810/1563 Loss 1.5437 Accuracy 0.5625
# Epoch 3 Step 820/1563 Loss 1.2651 Accuracy 0.5938
# Epoch 3 Step 830/1563 Loss 1.2630 Accuracy 0.5938
# Epoch 3 Step 840/1563 Loss 1.7672 Accuracy 0.3438
# Epoch 3 Step 850/1563 Loss 1.4873 Accuracy 0.4688
# Epoch 3 Step 860/1563 Loss 1.9273 Accuracy 0.5000
# Epoch 3 Step 870/1563 Loss 1.1828 Accuracy 0.5625
# Epoch 3 Step 880/1563 Loss 1.5163 Accuracy 0.4375
# Epoch 3 Step 890/1563 Loss 1.2564 Accuracy 0.4375
# Epoch 3 Step 900/1563 Loss 1.4688 Accuracy 0.5000
# Epoch 3 Step 910/1563 Loss 1.4359 Accuracy 0.4375
# Epoch 3 Step 920/1563 Loss 1.2055 Accuracy 0.5938
# Epoch 3 Step 930/1563 Loss 1.4401 Accuracy 0.5000
# Epoch 3 Step 940/1563 Loss 1.5701 Accuracy 0.3750
# Epoch 3 Step 950/1563 Loss 1.3958 Accuracy 0.5625
# Epoch 3 Step 960/1563 Loss 1.3507 Accuracy 0.5625
# Epoch 3 Step 970/1563 Loss 1.4077 Accuracy 0.4688
# Epoch 3 Step 980/1563 Loss 1.2160 Accuracy 0.4375
# Epoch 3 Step 990/1563 Loss 1.1715 Accuracy 0.5312
# Epoch 3 Step 1000/1563 Loss 1.3073 Accuracy 0.4688
# Epoch 3 Step 1010/1563 Loss 1.2021 Accuracy 0.5938
# Epoch 3 Step 1020/1563 Loss 1.1802 Accuracy 0.7188
# Epoch 3 Step 1030/1563 Loss 1.6143 Accuracy 0.5312
# Epoch 3 Step 1040/1563 Loss 1.2254 Accuracy 0.5000
# Epoch 3 Step 1050/1563 Loss 1.1050 Accuracy 0.6250
# Epoch 3 Step 1060/1563 Loss 1.1379 Accuracy 0.5625
# Epoch 3 Step 1070/1563 Loss 1.1198 Accuracy 0.6250
# Epoch 3 Step 1080/1563 Loss 1.1184 Accuracy 0.5625
# Epoch 3 Step 1090/1563 Loss 1.2197 Accuracy 0.4688
# Epoch 3 Step 1100/1563 Loss 1.2909 Accuracy 0.6250
# Epoch 3 Step 1110/1563 Loss 1.5950 Accuracy 0.5000
# Epoch 3 Step 1120/1563 Loss 1.9996 Accuracy 0.3750
# Epoch 3 Step 1130/1563 Loss 1.3101 Accuracy 0.3750
# Epoch 3 Step 1140/1563 Loss 1.4458 Accuracy 0.5312
# Epoch 3 Step 1150/1563 Loss 1.2706 Accuracy 0.4688
# Epoch 3 Step 1160/1563 Loss 1.1067 Accuracy 0.5938
# Epoch 3 Step 1170/1563 Loss 1.3804 Accuracy 0.4062
# Epoch 3 Step 1180/1563 Loss 1.2267 Accuracy 0.4062
# Epoch 3 Step 1190/1563 Loss 1.3852 Accuracy 0.5000
# Epoch 3 Step 1200/1563 Loss 1.2321 Accuracy 0.5938
# Epoch 3 Step 1210/1563 Loss 1.3076 Accuracy 0.5000
# Epoch 3 Step 1220/1563 Loss 1.3357 Accuracy 0.5000
# Epoch 3 Step 1230/1563 Loss 1.4513 Accuracy 0.4688
# Epoch 3 Step 1240/1563 Loss 1.2872 Accuracy 0.4688
# Epoch 3 Step 1250/1563 Loss 1.6002 Accuracy 0.4375
# Epoch 3 Step 1260/1563 Loss 1.3725 Accuracy 0.5000
# Epoch 3 Step 1270/1563 Loss 1.4240 Accuracy 0.5312
# Epoch 3 Step 1280/1563 Loss 1.5253 Accuracy 0.4375
# Epoch 3 Step 1290/1563 Loss 1.2312 Accuracy 0.5312
# Epoch 3 Step 1300/1563 Loss 1.2594 Accuracy 0.5000
# Epoch 3 Step 1310/1563 Loss 1.2784 Accuracy 0.5312
# Epoch 3 Step 1320/1563 Loss 1.2925 Accuracy 0.5625
# Epoch 3 Step 1330/1563 Loss 1.2026 Accuracy 0.5625
# Epoch 3 Step 1340/1563 Loss 1.1542 Accuracy 0.5000
# Epoch 3 Step 1350/1563 Loss 1.3105 Accuracy 0.4375
# Epoch 3 Step 1360/1563 Loss 1.1088 Accuracy 0.5938
# Epoch 3 Step 1370/1563 Loss 1.1932 Accuracy 0.5312
# Epoch 3 Step 1380/1563 Loss 1.2967 Accuracy 0.5000
# Epoch 3 Step 1390/1563 Loss 1.3895 Accuracy 0.4062
# Epoch 3 Step 1400/1563 Loss 1.4293 Accuracy 0.5000
# Epoch 3 Step 1410/1563 Loss 1.7482 Accuracy 0.3438
# Epoch 3 Step 1420/1563 Loss 1.2077 Accuracy 0.6250
# Epoch 3 Step 1430/1563 Loss 1.3073 Accuracy 0.6250
# Epoch 3 Step 1440/1563 Loss 1.1610 Accuracy 0.5000
# Epoch 3 Step 1450/1563 Loss 1.5916 Accuracy 0.4688
# Epoch 3 Step 1460/1563 Loss 0.9442 Accuracy 0.6875
# Epoch 3 Step 1470/1563 Loss 1.6706 Accuracy 0.3438
# Epoch 3 Step 1480/1563 Loss 1.4687 Accuracy 0.5938
# Epoch 3 Step 1490/1563 Loss 1.4419 Accuracy 0.5000
# Epoch 3 Step 1500/1563 Loss 1.0086 Accuracy 0.6250
# Epoch 3 Step 1510/1563 Loss 1.3007 Accuracy 0.5312
# Epoch 3 Step 1520/1563 Loss 0.9112 Accuracy 0.7188
# Epoch 3 Step 1530/1563 Loss 1.2626 Accuracy 0.5625
# Epoch 3 Step 1540/1563 Loss 1.5512 Accuracy 0.4688
# Epoch 3 Step 1550/1563 Loss 1.0667 Accuracy 0.7188
# Epoch 3 Step 1560/1563 Loss 1.1216 Accuracy 0.6250
# Epoch 3 / Accuracy 0.5442
# Epoch 4 Step 0/1563 Loss 1.2158 Accuracy 0.5938
# Epoch 4 Step 10/1563 Loss 1.2115 Accuracy 0.5625
# Epoch 4 Step 20/1563 Loss 1.3956 Accuracy 0.4688
# Epoch 4 Step 30/1563 Loss 1.2823 Accuracy 0.5312
# Epoch 4 Step 40/1563 Loss 1.1289 Accuracy 0.5938
# Epoch 4 Step 50/1563 Loss 1.2583 Accuracy 0.5000
# Epoch 4 Step 60/1563 Loss 1.2110 Accuracy 0.5625
# Epoch 4 Step 70/1563 Loss 1.4934 Accuracy 0.5312
# Epoch 4 Step 80/1563 Loss 1.2713 Accuracy 0.5938
# Epoch 4 Step 90/1563 Loss 1.2657 Accuracy 0.6250
# Epoch 4 Step 100/1563 Loss 1.2577 Accuracy 0.4688
# Epoch 4 Step 110/1563 Loss 1.2159 Accuracy 0.5625
# Epoch 4 Step 120/1563 Loss 1.6685 Accuracy 0.4688
# Epoch 4 Step 130/1563 Loss 1.2310 Accuracy 0.6562
# Epoch 4 Step 140/1563 Loss 1.6121 Accuracy 0.4062
# Epoch 4 Step 150/1563 Loss 1.3460 Accuracy 0.4688
# Epoch 4 Step 160/1563 Loss 1.1493 Accuracy 0.5938
# Epoch 4 Step 170/1563 Loss 1.0814 Accuracy 0.5312
# Epoch 4 Step 180/1563 Loss 1.2645 Accuracy 0.6562
# Epoch 4 Step 190/1563 Loss 1.2433 Accuracy 0.5625
# Epoch 4 Step 200/1563 Loss 1.6684 Accuracy 0.3750
# Epoch 4 Step 210/1563 Loss 1.2397 Accuracy 0.6562
# Epoch 4 Step 220/1563 Loss 1.5384 Accuracy 0.4688
# Epoch 4 Step 230/1563 Loss 1.3528 Accuracy 0.5000
# Epoch 4 Step 240/1563 Loss 1.6437 Accuracy 0.4375
# Epoch 4 Step 250/1563 Loss 1.1295 Accuracy 0.5312
# Epoch 4 Step 260/1563 Loss 1.0371 Accuracy 0.6250
# Epoch 4 Step 270/1563 Loss 1.1850 Accuracy 0.5938
# Epoch 4 Step 280/1563 Loss 0.9787 Accuracy 0.6250
# Epoch 4 Step 290/1563 Loss 1.3614 Accuracy 0.5312
# Epoch 4 Step 300/1563 Loss 1.0575 Accuracy 0.5938
# Epoch 4 Step 310/1563 Loss 1.6508 Accuracy 0.4375
# Epoch 4 Step 320/1563 Loss 1.3283 Accuracy 0.5000
# Epoch 4 Step 330/1563 Loss 0.9639 Accuracy 0.7500
# Epoch 4 Step 340/1563 Loss 1.5404 Accuracy 0.4688
# Epoch 4 Step 350/1563 Loss 1.0751 Accuracy 0.5625
# Epoch 4 Step 360/1563 Loss 1.3418 Accuracy 0.5625
# Epoch 4 Step 370/1563 Loss 1.1546 Accuracy 0.6250
# Epoch 4 Step 380/1563 Loss 1.4391 Accuracy 0.5625
# Epoch 4 Step 390/1563 Loss 1.2022 Accuracy 0.5938
# Epoch 4 Step 400/1563 Loss 1.1126 Accuracy 0.6562
# Epoch 4 Step 410/1563 Loss 1.3941 Accuracy 0.5625
# Epoch 4 Step 420/1563 Loss 1.0955 Accuracy 0.6875
# Epoch 4 Step 430/1563 Loss 1.5382 Accuracy 0.4688
# Epoch 4 Step 440/1563 Loss 1.5693 Accuracy 0.5312
# Epoch 4 Step 450/1563 Loss 1.1143 Accuracy 0.5312
# Epoch 4 Step 460/1563 Loss 1.3038 Accuracy 0.5312
# Epoch 4 Step 470/1563 Loss 1.3835 Accuracy 0.5000
# Epoch 4 Step 480/1563 Loss 1.0992 Accuracy 0.6562
# Epoch 4 Step 490/1563 Loss 1.3305 Accuracy 0.5625
# Epoch 4 Step 500/1563 Loss 1.3162 Accuracy 0.6562
# Epoch 4 Step 510/1563 Loss 1.3817 Accuracy 0.4688
# Epoch 4 Step 520/1563 Loss 0.9418 Accuracy 0.6250
# Epoch 4 Step 530/1563 Loss 1.6019 Accuracy 0.4688
# Epoch 4 Step 540/1563 Loss 1.2189 Accuracy 0.5625
# Epoch 4 Step 550/1563 Loss 1.2139 Accuracy 0.5938
# Epoch 4 Step 560/1563 Loss 1.0082 Accuracy 0.7812
# Epoch 4 Step 570/1563 Loss 1.0788 Accuracy 0.6250
# Epoch 4 Step 580/1563 Loss 1.3845 Accuracy 0.5938
# Epoch 4 Step 590/1563 Loss 1.1825 Accuracy 0.5625
# Epoch 4 Step 600/1563 Loss 1.4661 Accuracy 0.5000
# Epoch 4 Step 610/1563 Loss 1.2527 Accuracy 0.5000
# Epoch 4 Step 620/1563 Loss 1.0729 Accuracy 0.5312
# Epoch 4 Step 630/1563 Loss 1.2764 Accuracy 0.5938
# Epoch 4 Step 640/1563 Loss 1.2991 Accuracy 0.5000
# Epoch 4 Step 650/1563 Loss 1.1362 Accuracy 0.5625
# Epoch 4 Step 660/1563 Loss 1.0426 Accuracy 0.5938
# Epoch 4 Step 670/1563 Loss 1.0293 Accuracy 0.7500
# Epoch 4 Step 680/1563 Loss 1.4773 Accuracy 0.5312
# Epoch 4 Step 690/1563 Loss 1.3838 Accuracy 0.5312
# Epoch 4 Step 700/1563 Loss 1.1983 Accuracy 0.5312
# Epoch 4 Step 710/1563 Loss 1.2887 Accuracy 0.4375
# Epoch 4 Step 720/1563 Loss 1.5083 Accuracy 0.3125
# Epoch 4 Step 730/1563 Loss 1.4000 Accuracy 0.5312
# Epoch 4 Step 740/1563 Loss 1.6284 Accuracy 0.3438
# Epoch 4 Step 750/1563 Loss 1.5191 Accuracy 0.4375
# Epoch 4 Step 760/1563 Loss 1.1724 Accuracy 0.5625
# Epoch 4 Step 770/1563 Loss 1.3866 Accuracy 0.4375
# Epoch 4 Step 780/1563 Loss 1.2171 Accuracy 0.6250
# Epoch 4 Step 790/1563 Loss 1.2166 Accuracy 0.6250
# Epoch 4 Step 800/1563 Loss 1.0803 Accuracy 0.6250
# Epoch 4 Step 810/1563 Loss 1.6024 Accuracy 0.4688
# Epoch 4 Step 820/1563 Loss 1.1725 Accuracy 0.6875
# Epoch 4 Step 830/1563 Loss 1.1773 Accuracy 0.6562
# Epoch 4 Step 840/1563 Loss 1.1371 Accuracy 0.5312
# Epoch 4 Step 850/1563 Loss 1.5229 Accuracy 0.4688
# Epoch 4 Step 860/1563 Loss 1.1045 Accuracy 0.7188
# Epoch 4 Step 870/1563 Loss 1.2318 Accuracy 0.5625
# Epoch 4 Step 880/1563 Loss 1.7366 Accuracy 0.3125
# Epoch 4 Step 890/1563 Loss 1.3511 Accuracy 0.5625
# Epoch 4 Step 900/1563 Loss 1.1869 Accuracy 0.5312
# Epoch 4 Step 910/1563 Loss 1.2704 Accuracy 0.5312
# Epoch 4 Step 920/1563 Loss 1.2555 Accuracy 0.6562
# Epoch 4 Step 930/1563 Loss 1.1147 Accuracy 0.5938
# Epoch 4 Step 940/1563 Loss 1.3547 Accuracy 0.5312
# Epoch 4 Step 950/1563 Loss 1.4640 Accuracy 0.5000
# Epoch 4 Step 960/1563 Loss 1.3557 Accuracy 0.5312
# Epoch 4 Step 970/1563 Loss 1.5433 Accuracy 0.4375
# Epoch 4 Step 980/1563 Loss 0.9466 Accuracy 0.6875
# Epoch 4 Step 990/1563 Loss 1.3738 Accuracy 0.4688
# Epoch 4 Step 1000/1563 Loss 1.1165 Accuracy 0.6250
# Epoch 4 Step 1010/1563 Loss 1.2416 Accuracy 0.6250
# Epoch 4 Step 1020/1563 Loss 1.2344 Accuracy 0.6250
# Epoch 4 Step 1030/1563 Loss 1.1170 Accuracy 0.5938
# Epoch 4 Step 1040/1563 Loss 1.0957 Accuracy 0.5938
# Epoch 4 Step 1050/1563 Loss 1.2941 Accuracy 0.5938
# Epoch 4 Step 1060/1563 Loss 1.1974 Accuracy 0.7188
# Epoch 4 Step 1070/1563 Loss 1.0909 Accuracy 0.6250
# Epoch 4 Step 1080/1563 Loss 1.0647 Accuracy 0.6562
# Epoch 4 Step 1090/1563 Loss 1.1876 Accuracy 0.6250
# Epoch 4 Step 1100/1563 Loss 1.0911 Accuracy 0.6562
# Epoch 4 Step 1110/1563 Loss 1.3158 Accuracy 0.6562
# Epoch 4 Step 1120/1563 Loss 1.3904 Accuracy 0.4688
# Epoch 4 Step 1130/1563 Loss 1.4581 Accuracy 0.4688
# Epoch 4 Step 1140/1563 Loss 1.5910 Accuracy 0.4375
# Epoch 4 Step 1150/1563 Loss 1.3258 Accuracy 0.5000
# Epoch 4 Step 1160/1563 Loss 1.0854 Accuracy 0.6250
# Epoch 4 Step 1170/1563 Loss 1.0799 Accuracy 0.6875
# Epoch 4 Step 1180/1563 Loss 1.3911 Accuracy 0.5000
# Epoch 4 Step 1190/1563 Loss 1.3642 Accuracy 0.5938
# Epoch 4 Step 1200/1563 Loss 0.9183 Accuracy 0.6562
# Epoch 4 Step 1210/1563 Loss 1.3319 Accuracy 0.5625
# Epoch 4 Step 1220/1563 Loss 1.4918 Accuracy 0.4375
# Epoch 4 Step 1230/1563 Loss 1.5446 Accuracy 0.4688
# Epoch 4 Step 1240/1563 Loss 1.1506 Accuracy 0.5312
# Epoch 4 Step 1250/1563 Loss 1.3112 Accuracy 0.4375
# Epoch 4 Step 1260/1563 Loss 1.3104 Accuracy 0.5312
# Epoch 4 Step 1270/1563 Loss 1.4080 Accuracy 0.5938
# Epoch 4 Step 1280/1563 Loss 1.2448 Accuracy 0.5625
# Epoch 4 Step 1290/1563 Loss 1.4615 Accuracy 0.5312
# Epoch 4 Step 1300/1563 Loss 1.2850 Accuracy 0.5625
# Epoch 4 Step 1310/1563 Loss 1.0244 Accuracy 0.6562
# Epoch 4 Step 1320/1563 Loss 1.1341 Accuracy 0.4688
# Epoch 4 Step 1330/1563 Loss 1.1164 Accuracy 0.5625
# Epoch 4 Step 1340/1563 Loss 1.2232 Accuracy 0.6562
# Epoch 4 Step 1350/1563 Loss 1.3350 Accuracy 0.5625
# Epoch 4 Step 1360/1563 Loss 1.2984 Accuracy 0.5312
# Epoch 4 Step 1370/1563 Loss 1.3013 Accuracy 0.5938
# Epoch 4 Step 1380/1563 Loss 1.5903 Accuracy 0.5625
# Epoch 4 Step 1390/1563 Loss 1.0111 Accuracy 0.5938
# Epoch 4 Step 1400/1563 Loss 1.3379 Accuracy 0.5938
# Epoch 4 Step 1410/1563 Loss 1.2288 Accuracy 0.5625
# Epoch 4 Step 1420/1563 Loss 1.3219 Accuracy 0.6250
# Epoch 4 Step 1430/1563 Loss 1.1551 Accuracy 0.5625
# Epoch 4 Step 1440/1563 Loss 0.9789 Accuracy 0.6562
# Epoch 4 Step 1450/1563 Loss 1.1001 Accuracy 0.5625
# Epoch 4 Step 1460/1563 Loss 1.0713 Accuracy 0.5312
# Epoch 4 Step 1470/1563 Loss 1.1583 Accuracy 0.6250
# Epoch 4 Step 1480/1563 Loss 1.4918 Accuracy 0.4688
# Epoch 4 Step 1490/1563 Loss 1.2695 Accuracy 0.5938
# Epoch 4 Step 1500/1563 Loss 1.1266 Accuracy 0.7188
# Epoch 4 Step 1510/1563 Loss 1.0874 Accuracy 0.5625
# Epoch 4 Step 1520/1563 Loss 1.0250 Accuracy 0.7188
# Epoch 4 Step 1530/1563 Loss 1.4375 Accuracy 0.4688
# Epoch 4 Step 1540/1563 Loss 1.4341 Accuracy 0.3750
# Epoch 4 Step 1550/1563 Loss 1.3044 Accuracy 0.5000
# Epoch 4 Step 1560/1563 Loss 1.2857 Accuracy 0.5312
# Epoch 4 / Accuracy 0.5381
# Epoch 5 Step 0/1563 Loss 1.1953 Accuracy 0.5625
# Epoch 5 Step 10/1563 Loss 1.5116 Accuracy 0.5625
# Epoch 5 Step 20/1563 Loss 1.4330 Accuracy 0.4688
# Epoch 5 Step 30/1563 Loss 1.3677 Accuracy 0.5312
# Epoch 5 Step 40/1563 Loss 1.3636 Accuracy 0.5625
# Epoch 5 Step 50/1563 Loss 1.5895 Accuracy 0.5312
# Epoch 5 Step 60/1563 Loss 1.2781 Accuracy 0.6250
# Epoch 5 Step 70/1563 Loss 1.0421 Accuracy 0.6875
# Epoch 5 Step 80/1563 Loss 1.1927 Accuracy 0.6562
# Epoch 5 Step 90/1563 Loss 0.9533 Accuracy 0.6562
# Epoch 5 Step 100/1563 Loss 1.0201 Accuracy 0.6875
# Epoch 5 Step 110/1563 Loss 1.3756 Accuracy 0.5000
# Epoch 5 Step 120/1563 Loss 1.4054 Accuracy 0.5312
# Epoch 5 Step 130/1563 Loss 1.2511 Accuracy 0.6875
# Epoch 5 Step 140/1563 Loss 1.1192 Accuracy 0.5312
# Epoch 5 Step 150/1563 Loss 0.9746 Accuracy 0.6875
# Epoch 5 Step 160/1563 Loss 1.3218 Accuracy 0.4688
# Epoch 5 Step 170/1563 Loss 0.9019 Accuracy 0.6250
# Epoch 5 Step 180/1563 Loss 1.1343 Accuracy 0.6250
# Epoch 5 Step 190/1563 Loss 1.6706 Accuracy 0.4688
# Epoch 5 Step 200/1563 Loss 0.7235 Accuracy 0.7812
# Epoch 5 Step 210/1563 Loss 1.1823 Accuracy 0.5625
# Epoch 5 Step 220/1563 Loss 1.2206 Accuracy 0.5312
# Epoch 5 Step 230/1563 Loss 1.2020 Accuracy 0.5625
# Epoch 5 Step 240/1563 Loss 1.1023 Accuracy 0.6250
# Epoch 5 Step 250/1563 Loss 0.7845 Accuracy 0.7812
# Epoch 5 Step 260/1563 Loss 0.9263 Accuracy 0.7188
# Epoch 5 Step 270/1563 Loss 1.2749 Accuracy 0.5625
# Epoch 5 Step 280/1563 Loss 1.6404 Accuracy 0.4375
# Epoch 5 Step 290/1563 Loss 1.8650 Accuracy 0.3125
# Epoch 5 Step 300/1563 Loss 0.8518 Accuracy 0.7188
# Epoch 5 Step 310/1563 Loss 1.1680 Accuracy 0.6562
# Epoch 5 Step 320/1563 Loss 1.2920 Accuracy 0.5938
# Epoch 5 Step 330/1563 Loss 1.1275 Accuracy 0.5625
# Epoch 5 Step 340/1563 Loss 1.4817 Accuracy 0.5625
# Epoch 5 Step 350/1563 Loss 1.5145 Accuracy 0.5312
# Epoch 5 Step 360/1563 Loss 1.3245 Accuracy 0.5312
# Epoch 5 Step 370/1563 Loss 1.1421 Accuracy 0.5938
# Epoch 5 Step 380/1563 Loss 1.3713 Accuracy 0.5000
# Epoch 5 Step 390/1563 Loss 0.8613 Accuracy 0.6875
# Epoch 5 Step 400/1563 Loss 0.8860 Accuracy 0.6250
# Epoch 5 Step 410/1563 Loss 1.4467 Accuracy 0.5000
# Epoch 5 Step 420/1563 Loss 1.5048 Accuracy 0.3750
# Epoch 5 Step 430/1563 Loss 1.0349 Accuracy 0.6562
# Epoch 5 Step 440/1563 Loss 1.1395 Accuracy 0.4688
# Epoch 5 Step 450/1563 Loss 1.2083 Accuracy 0.6250
# Epoch 5 Step 460/1563 Loss 0.9842 Accuracy 0.7500
# Epoch 5 Step 470/1563 Loss 1.3016 Accuracy 0.5938
# Epoch 5 Step 480/1563 Loss 1.1993 Accuracy 0.6562
# Epoch 5 Step 490/1563 Loss 1.3306 Accuracy 0.3750
# Epoch 5 Step 500/1563 Loss 0.8428 Accuracy 0.6562
# Epoch 5 Step 510/1563 Loss 0.9489 Accuracy 0.7188
# Epoch 5 Step 520/1563 Loss 0.8090 Accuracy 0.7812
# Epoch 5 Step 530/1563 Loss 1.1062 Accuracy 0.6250
# Epoch 5 Step 540/1563 Loss 1.1357 Accuracy 0.6875
# Epoch 5 Step 550/1563 Loss 1.1914 Accuracy 0.4688
# Epoch 5 Step 560/1563 Loss 1.5405 Accuracy 0.4688
# Epoch 5 Step 570/1563 Loss 1.4134 Accuracy 0.5312
# Epoch 5 Step 580/1563 Loss 1.4788 Accuracy 0.4688
# Epoch 5 Step 590/1563 Loss 1.0512 Accuracy 0.6562
# Epoch 5 Step 600/1563 Loss 1.2273 Accuracy 0.6250
# Epoch 5 Step 610/1563 Loss 0.9768 Accuracy 0.6562
# Epoch 5 Step 620/1563 Loss 1.1214 Accuracy 0.6250
# Epoch 5 Step 630/1563 Loss 1.2053 Accuracy 0.5000
# Epoch 5 Step 640/1563 Loss 1.4978 Accuracy 0.5312
# Epoch 5 Step 650/1563 Loss 1.2205 Accuracy 0.5938
# Epoch 5 Step 660/1563 Loss 1.1522 Accuracy 0.5625
# Epoch 5 Step 670/1563 Loss 0.9124 Accuracy 0.6875
# Epoch 5 Step 680/1563 Loss 1.1948 Accuracy 0.6250
# Epoch 5 Step 690/1563 Loss 1.4276 Accuracy 0.4375
# Epoch 5 Step 700/1563 Loss 1.4867 Accuracy 0.4688
# Epoch 5 Step 710/1563 Loss 0.9434 Accuracy 0.6875
# Epoch 5 Step 720/1563 Loss 1.3076 Accuracy 0.5938
# Epoch 5 Step 730/1563 Loss 1.0071 Accuracy 0.5938
# Epoch 5 Step 740/1563 Loss 1.5013 Accuracy 0.5000
# Epoch 5 Step 750/1563 Loss 1.3071 Accuracy 0.6250
# Epoch 5 Step 760/1563 Loss 1.0000 Accuracy 0.6875
# Epoch 5 Step 770/1563 Loss 1.0216 Accuracy 0.6875
# Epoch 5 Step 780/1563 Loss 1.7127 Accuracy 0.5000
# Epoch 5 Step 790/1563 Loss 1.0783 Accuracy 0.6250
# Epoch 5 Step 800/1563 Loss 1.3936 Accuracy 0.4062
# Epoch 5 Step 810/1563 Loss 0.9821 Accuracy 0.5312
# Epoch 5 Step 820/1563 Loss 1.0167 Accuracy 0.6562
# Epoch 5 Step 830/1563 Loss 1.3739 Accuracy 0.5000
# Epoch 5 Step 840/1563 Loss 1.3551 Accuracy 0.4375
# Epoch 5 Step 850/1563 Loss 1.7616 Accuracy 0.4062
# Epoch 5 Step 860/1563 Loss 1.1223 Accuracy 0.5625
# Epoch 5 Step 870/1563 Loss 1.0198 Accuracy 0.6875
# Epoch 5 Step 880/1563 Loss 0.9511 Accuracy 0.6875
# Epoch 5 Step 890/1563 Loss 1.1583 Accuracy 0.5938
# Epoch 5 Step 900/1563 Loss 1.0019 Accuracy 0.5938
# Epoch 5 Step 910/1563 Loss 1.5251 Accuracy 0.5625
# Epoch 5 Step 920/1563 Loss 0.9022 Accuracy 0.5938
# Epoch 5 Step 930/1563 Loss 1.1602 Accuracy 0.6875
# Epoch 5 Step 940/1563 Loss 1.4852 Accuracy 0.5000
# Epoch 5 Step 950/1563 Loss 1.2996 Accuracy 0.5312
# Epoch 5 Step 960/1563 Loss 1.1523 Accuracy 0.6562
# Epoch 5 Step 970/1563 Loss 0.8379 Accuracy 0.7500
# Epoch 5 Step 980/1563 Loss 1.1862 Accuracy 0.6250
# Epoch 5 Step 990/1563 Loss 1.1476 Accuracy 0.5938
# Epoch 5 Step 1000/1563 Loss 1.2320 Accuracy 0.6875
# Epoch 5 Step 1010/1563 Loss 1.1925 Accuracy 0.5625
# Epoch 5 Step 1020/1563 Loss 1.1766 Accuracy 0.6875
# Epoch 5 Step 1030/1563 Loss 1.3982 Accuracy 0.5938
# Epoch 5 Step 1040/1563 Loss 1.0992 Accuracy 0.6875
# Epoch 5 Step 1050/1563 Loss 1.3615 Accuracy 0.4062
# Epoch 5 Step 1060/1563 Loss 1.2081 Accuracy 0.6562
# Epoch 5 Step 1070/1563 Loss 1.4614 Accuracy 0.3750
# Epoch 5 Step 1080/1563 Loss 0.9214 Accuracy 0.6875
# Epoch 5 Step 1090/1563 Loss 1.2792 Accuracy 0.6562
# Epoch 5 Step 1100/1563 Loss 1.0932 Accuracy 0.6250
# Epoch 5 Step 1110/1563 Loss 1.6831 Accuracy 0.4062
# Epoch 5 Step 1120/1563 Loss 0.8926 Accuracy 0.7500
# Epoch 5 Step 1130/1563 Loss 1.2370 Accuracy 0.5625
# Epoch 5 Step 1140/1563 Loss 1.1166 Accuracy 0.6250
# Epoch 5 Step 1150/1563 Loss 1.2745 Accuracy 0.5938
# Epoch 5 Step 1160/1563 Loss 1.2209 Accuracy 0.6250
# Epoch 5 Step 1170/1563 Loss 1.1505 Accuracy 0.6250
# Epoch 5 Step 1180/1563 Loss 0.8991 Accuracy 0.6250
# Epoch 5 Step 1190/1563 Loss 1.1691 Accuracy 0.6250
# Epoch 5 Step 1200/1563 Loss 1.1901 Accuracy 0.6562
# Epoch 5 Step 1210/1563 Loss 1.0504 Accuracy 0.6875
# Epoch 5 Step 1220/1563 Loss 1.8753 Accuracy 0.5000
# Epoch 5 Step 1230/1563 Loss 1.3130 Accuracy 0.5625
# Epoch 5 Step 1240/1563 Loss 1.3237 Accuracy 0.5312
# Epoch 5 Step 1250/1563 Loss 0.9620 Accuracy 0.7188
# Epoch 5 Step 1260/1563 Loss 1.0865 Accuracy 0.7500
# Epoch 5 Step 1270/1563 Loss 1.1408 Accuracy 0.4688
# Epoch 5 Step 1280/1563 Loss 0.9280 Accuracy 0.7500
# Epoch 5 Step 1290/1563 Loss 1.3044 Accuracy 0.4688
# Epoch 5 Step 1300/1563 Loss 0.9583 Accuracy 0.6250
# Epoch 5 Step 1310/1563 Loss 1.2574 Accuracy 0.5000
# Epoch 5 Step 1320/1563 Loss 1.0201 Accuracy 0.5625
# Epoch 5 Step 1330/1563 Loss 0.8431 Accuracy 0.8750
# Epoch 5 Step 1340/1563 Loss 1.1597 Accuracy 0.5625
# Epoch 5 Step 1350/1563 Loss 1.1373 Accuracy 0.6562
# Epoch 5 Step 1360/1563 Loss 1.1038 Accuracy 0.5938
# Epoch 5 Step 1370/1563 Loss 1.3146 Accuracy 0.5312
# Epoch 5 Step 1380/1563 Loss 1.3806 Accuracy 0.4375
# Epoch 5 Step 1390/1563 Loss 0.9917 Accuracy 0.7188
# Epoch 5 Step 1400/1563 Loss 1.1305 Accuracy 0.5938
# Epoch 5 Step 1410/1563 Loss 1.3205 Accuracy 0.5938
# Epoch 5 Step 1420/1563 Loss 1.2760 Accuracy 0.5625
# Epoch 5 Step 1430/1563 Loss 0.7922 Accuracy 0.7500
# Epoch 5 Step 1440/1563 Loss 1.2809 Accuracy 0.5000
# Epoch 5 Step 1450/1563 Loss 1.5588 Accuracy 0.5000
# Epoch 5 Step 1460/1563 Loss 0.9627 Accuracy 0.6875
# Epoch 5 Step 1470/1563 Loss 1.1564 Accuracy 0.5625
# Epoch 5 Step 1480/1563 Loss 1.5642 Accuracy 0.4375
# Epoch 5 Step 1490/1563 Loss 1.4804 Accuracy 0.5000
# Epoch 5 Step 1500/1563 Loss 1.0416 Accuracy 0.6250
# Epoch 5 Step 1510/1563 Loss 1.1724 Accuracy 0.6875
# Epoch 5 Step 1520/1563 Loss 1.2375 Accuracy 0.5312
# Epoch 5 Step 1530/1563 Loss 0.8878 Accuracy 0.6875
# Epoch 5 Step 1540/1563 Loss 1.2931 Accuracy 0.5625
# Epoch 5 Step 1550/1563 Loss 1.1200 Accuracy 0.6562
# Epoch 5 Step 1560/1563 Loss 1.0323 Accuracy 0.6250
# Epoch 5 / Accuracy 0.6072
# Epoch 6 Step 0/1563 Loss 0.8513 Accuracy 0.7500
# Epoch 6 Step 10/1563 Loss 1.3557 Accuracy 0.4375
# Epoch 6 Step 20/1563 Loss 0.7085 Accuracy 0.7812
# Epoch 6 Step 30/1563 Loss 1.3315 Accuracy 0.5000
# Epoch 6 Step 40/1563 Loss 1.0070 Accuracy 0.5938
# Epoch 6 Step 50/1563 Loss 1.3099 Accuracy 0.5312
# Epoch 6 Step 60/1563 Loss 1.3808 Accuracy 0.5000
# Epoch 6 Step 70/1563 Loss 1.2267 Accuracy 0.5938
# Epoch 6 Step 80/1563 Loss 1.0773 Accuracy 0.6562
# Epoch 6 Step 90/1563 Loss 1.0765 Accuracy 0.7188
# Epoch 6 Step 100/1563 Loss 1.1494 Accuracy 0.5938
# Epoch 6 Step 110/1563 Loss 1.1914 Accuracy 0.6562
# Epoch 6 Step 120/1563 Loss 1.1845 Accuracy 0.6562
# Epoch 6 Step 130/1563 Loss 1.3094 Accuracy 0.5312
# Epoch 6 Step 140/1563 Loss 1.2997 Accuracy 0.5312
# Epoch 6 Step 150/1563 Loss 1.1655 Accuracy 0.5312
# Epoch 6 Step 160/1563 Loss 0.9582 Accuracy 0.6250
# Epoch 6 Step 170/1563 Loss 1.0251 Accuracy 0.7188
# Epoch 6 Step 180/1563 Loss 1.2382 Accuracy 0.5312
# Epoch 6 Step 190/1563 Loss 1.1639 Accuracy 0.5938
# Epoch 6 Step 200/1563 Loss 1.2449 Accuracy 0.4688
# Epoch 6 Step 210/1563 Loss 1.0928 Accuracy 0.6562
# Epoch 6 Step 220/1563 Loss 1.1568 Accuracy 0.6562
# Epoch 6 Step 230/1563 Loss 1.0756 Accuracy 0.5938
# Epoch 6 Step 240/1563 Loss 1.1817 Accuracy 0.5625
# Epoch 6 Step 250/1563 Loss 1.1687 Accuracy 0.5938
# Epoch 6 Step 260/1563 Loss 0.8497 Accuracy 0.7812
# Epoch 6 Step 270/1563 Loss 1.2471 Accuracy 0.5625
# Epoch 6 Step 280/1563 Loss 0.8004 Accuracy 0.8438
# Epoch 6 Step 290/1563 Loss 1.0018 Accuracy 0.6250
# Epoch 6 Step 300/1563 Loss 1.2066 Accuracy 0.5938
# Epoch 6 Step 310/1563 Loss 1.1341 Accuracy 0.5938
# Epoch 6 Step 320/1563 Loss 1.3420 Accuracy 0.5312
# Epoch 6 Step 330/1563 Loss 1.2219 Accuracy 0.5000
# Epoch 6 Step 340/1563 Loss 0.8196 Accuracy 0.7500
# Epoch 6 Step 350/1563 Loss 1.4258 Accuracy 0.5312
# Epoch 6 Step 360/1563 Loss 1.0215 Accuracy 0.5938
# Epoch 6 Step 370/1563 Loss 1.2724 Accuracy 0.6250
# Epoch 6 Step 380/1563 Loss 0.9305 Accuracy 0.6562
# Epoch 6 Step 390/1563 Loss 0.8772 Accuracy 0.6875
# Epoch 6 Step 400/1563 Loss 1.1071 Accuracy 0.6250
# Epoch 6 Step 410/1563 Loss 0.9881 Accuracy 0.6875
# Epoch 6 Step 420/1563 Loss 1.2969 Accuracy 0.5000
# Epoch 6 Step 430/1563 Loss 1.0583 Accuracy 0.5938
# Epoch 6 Step 440/1563 Loss 1.0834 Accuracy 0.6875
# Epoch 6 Step 450/1563 Loss 1.2106 Accuracy 0.6250
# Epoch 6 Step 460/1563 Loss 1.0210 Accuracy 0.6562
# Epoch 6 Step 470/1563 Loss 1.1570 Accuracy 0.6250
# Epoch 6 Step 480/1563 Loss 1.2333 Accuracy 0.5938
# Epoch 6 Step 490/1563 Loss 1.2693 Accuracy 0.5625
# Epoch 6 Step 500/1563 Loss 1.2273 Accuracy 0.4062
# Epoch 6 Step 510/1563 Loss 0.9771 Accuracy 0.6250
# Epoch 6 Step 520/1563 Loss 1.1032 Accuracy 0.6250
# Epoch 6 Step 530/1563 Loss 1.1686 Accuracy 0.5625
# Epoch 6 Step 540/1563 Loss 1.7777 Accuracy 0.3750
# Epoch 6 Step 550/1563 Loss 1.6476 Accuracy 0.4688
# Epoch 6 Step 560/1563 Loss 1.1565 Accuracy 0.4688
# Epoch 6 Step 570/1563 Loss 1.0901 Accuracy 0.5938
# Epoch 6 Step 580/1563 Loss 1.4445 Accuracy 0.6250
# Epoch 6 Step 590/1563 Loss 1.2740 Accuracy 0.5625
# Epoch 6 Step 600/1563 Loss 1.1977 Accuracy 0.5625
# Epoch 6 Step 610/1563 Loss 1.2601 Accuracy 0.6250
# Epoch 6 Step 620/1563 Loss 1.3285 Accuracy 0.5938
# Epoch 6 Step 630/1563 Loss 1.1873 Accuracy 0.5938
# Epoch 6 Step 640/1563 Loss 0.9018 Accuracy 0.6562
# Epoch 6 Step 650/1563 Loss 0.8184 Accuracy 0.7188
# Epoch 6 Step 660/1563 Loss 0.9675 Accuracy 0.6250
# Epoch 6 Step 670/1563 Loss 0.9790 Accuracy 0.8125
# Epoch 6 Step 680/1563 Loss 0.9672 Accuracy 0.5938
# Epoch 6 Step 690/1563 Loss 1.1173 Accuracy 0.7500
# Epoch 6 Step 700/1563 Loss 0.9885 Accuracy 0.6250
# Epoch 6 Step 710/1563 Loss 1.6489 Accuracy 0.4062
# Epoch 6 Step 720/1563 Loss 0.8331 Accuracy 0.7188
# Epoch 6 Step 730/1563 Loss 1.2208 Accuracy 0.6562
# Epoch 6 Step 740/1563 Loss 0.9828 Accuracy 0.6250
# Epoch 6 Step 750/1563 Loss 1.4260 Accuracy 0.5000
# Epoch 6 Step 760/1563 Loss 1.0143 Accuracy 0.6875
# Epoch 6 Step 770/1563 Loss 1.0202 Accuracy 0.5938
# Epoch 6 Step 780/1563 Loss 0.9203 Accuracy 0.6250
# Epoch 6 Step 790/1563 Loss 1.2136 Accuracy 0.6250
# Epoch 6 Step 800/1563 Loss 1.2487 Accuracy 0.5938
# Epoch 6 Step 810/1563 Loss 1.1117 Accuracy 0.6875
# Epoch 6 Step 820/1563 Loss 1.1763 Accuracy 0.5625
# Epoch 6 Step 830/1563 Loss 1.1211 Accuracy 0.4688
# Epoch 6 Step 840/1563 Loss 0.9690 Accuracy 0.5938
# Epoch 6 Step 850/1563 Loss 0.8297 Accuracy 0.8125
# Epoch 6 Step 860/1563 Loss 1.2806 Accuracy 0.6562
# Epoch 6 Step 870/1563 Loss 1.0202 Accuracy 0.6562
# Epoch 6 Step 880/1563 Loss 0.9634 Accuracy 0.6562
# Epoch 6 Step 890/1563 Loss 1.3618 Accuracy 0.5000
# Epoch 6 Step 900/1563 Loss 1.4298 Accuracy 0.5625
# Epoch 6 Step 910/1563 Loss 1.2409 Accuracy 0.5625
# Epoch 6 Step 920/1563 Loss 0.9034 Accuracy 0.6562
# Epoch 6 Step 930/1563 Loss 0.9926 Accuracy 0.5938
# Epoch 6 Step 940/1563 Loss 1.3052 Accuracy 0.4375
# Epoch 6 Step 950/1563 Loss 1.1540 Accuracy 0.6562
# Epoch 6 Step 960/1563 Loss 1.2496 Accuracy 0.5000
# Epoch 6 Step 970/1563 Loss 1.0695 Accuracy 0.6875
# Epoch 6 Step 980/1563 Loss 0.8987 Accuracy 0.7812
# Epoch 6 Step 990/1563 Loss 0.8810 Accuracy 0.7188
# Epoch 6 Step 1000/1563 Loss 1.1018 Accuracy 0.5938
# Epoch 6 Step 1010/1563 Loss 1.3958 Accuracy 0.5625
# Epoch 6 Step 1020/1563 Loss 1.0487 Accuracy 0.6562
# Epoch 6 Step 1030/1563 Loss 0.8877 Accuracy 0.6250
# Epoch 6 Step 1040/1563 Loss 1.0031 Accuracy 0.6562
# Epoch 6 Step 1050/1563 Loss 1.1277 Accuracy 0.5938
# Epoch 6 Step 1060/1563 Loss 1.4574 Accuracy 0.5625
# Epoch 6 Step 1070/1563 Loss 1.0711 Accuracy 0.6562
# Epoch 6 Step 1080/1563 Loss 0.7129 Accuracy 0.6875
# Epoch 6 Step 1090/1563 Loss 1.1137 Accuracy 0.6250
# Epoch 6 Step 1100/1563 Loss 1.0993 Accuracy 0.6250
# Epoch 6 Step 1110/1563 Loss 1.3086 Accuracy 0.4688
# Epoch 6 Step 1120/1563 Loss 1.2887 Accuracy 0.5312
# Epoch 6 Step 1130/1563 Loss 1.2373 Accuracy 0.5000
# Epoch 6 Step 1140/1563 Loss 1.1080 Accuracy 0.6250
# Epoch 6 Step 1150/1563 Loss 1.1184 Accuracy 0.6250
# Epoch 6 Step 1160/1563 Loss 0.7578 Accuracy 0.7812
# Epoch 6 Step 1170/1563 Loss 0.9645 Accuracy 0.6875
# Epoch 6 Step 1180/1563 Loss 1.0348 Accuracy 0.6562
# Epoch 6 Step 1190/1563 Loss 0.8442 Accuracy 0.7812
# Epoch 6 Step 1200/1563 Loss 1.2586 Accuracy 0.5000
# Epoch 6 Step 1210/1563 Loss 1.5727 Accuracy 0.6250
# Epoch 6 Step 1220/1563 Loss 1.0487 Accuracy 0.5938
# Epoch 6 Step 1230/1563 Loss 1.0409 Accuracy 0.6875
# Epoch 6 Step 1240/1563 Loss 1.1665 Accuracy 0.5000
# Epoch 6 Step 1250/1563 Loss 0.9542 Accuracy 0.6875
# Epoch 6 Step 1260/1563 Loss 1.1688 Accuracy 0.5625
# Epoch 6 Step 1270/1563 Loss 0.7944 Accuracy 0.7500
# Epoch 6 Step 1280/1563 Loss 1.0954 Accuracy 0.5312
# Epoch 6 Step 1290/1563 Loss 1.3233 Accuracy 0.5625
# Epoch 6 Step 1300/1563 Loss 1.6395 Accuracy 0.4062
# Epoch 6 Step 1310/1563 Loss 0.9772 Accuracy 0.7188
# Epoch 6 Step 1320/1563 Loss 1.1664 Accuracy 0.6250
# Epoch 6 Step 1330/1563 Loss 0.8205 Accuracy 0.7500
# Epoch 6 Step 1340/1563 Loss 1.2841 Accuracy 0.4375
# Epoch 6 Step 1350/1563 Loss 1.4021 Accuracy 0.5625
# Epoch 6 Step 1360/1563 Loss 1.3290 Accuracy 0.6250
# Epoch 6 Step 1370/1563 Loss 0.9479 Accuracy 0.7500
# Epoch 6 Step 1380/1563 Loss 0.9331 Accuracy 0.6875
# Epoch 6 Step 1390/1563 Loss 0.7552 Accuracy 0.7500
# Epoch 6 Step 1400/1563 Loss 1.1728 Accuracy 0.5312
# Epoch 6 Step 1410/1563 Loss 1.3022 Accuracy 0.5625
# Epoch 6 Step 1420/1563 Loss 1.2095 Accuracy 0.5625
# Epoch 6 Step 1430/1563 Loss 0.8131 Accuracy 0.6875
# Epoch 6 Step 1440/1563 Loss 1.1177 Accuracy 0.5312
# Epoch 6 Step 1450/1563 Loss 1.0298 Accuracy 0.6562
# Epoch 6 Step 1460/1563 Loss 0.9930 Accuracy 0.6250
# Epoch 6 Step 1470/1563 Loss 0.9368 Accuracy 0.6875
# Epoch 6 Step 1480/1563 Loss 1.1211 Accuracy 0.5312
# Epoch 6 Step 1490/1563 Loss 1.5390 Accuracy 0.4688
# Epoch 6 Step 1500/1563 Loss 1.0630 Accuracy 0.6875
# Epoch 6 Step 1510/1563 Loss 0.9468 Accuracy 0.6562
# Epoch 6 Step 1520/1563 Loss 1.2482 Accuracy 0.5625
# Epoch 6 Step 1530/1563 Loss 1.2083 Accuracy 0.6250
# Epoch 6 Step 1540/1563 Loss 0.9338 Accuracy 0.6562
# Epoch 6 Step 1550/1563 Loss 1.2759 Accuracy 0.6562
# Epoch 6 Step 1560/1563 Loss 1.0518 Accuracy 0.7500
# Epoch 6 / Accuracy 0.6158
# Epoch 7 Step 0/1563 Loss 0.8515 Accuracy 0.8125
# Epoch 7 Step 10/1563 Loss 1.0051 Accuracy 0.5938
# Epoch 7 Step 20/1563 Loss 1.4021 Accuracy 0.5000
# Epoch 7 Step 30/1563 Loss 0.9669 Accuracy 0.7188
# Epoch 7 Step 40/1563 Loss 1.0794 Accuracy 0.6875
# Epoch 7 Step 50/1563 Loss 1.1728 Accuracy 0.7188
# Epoch 7 Step 60/1563 Loss 1.0663 Accuracy 0.6250
# Epoch 7 Step 70/1563 Loss 1.3103 Accuracy 0.6250
# Epoch 7 Step 80/1563 Loss 1.1682 Accuracy 0.6875
# ...
# Epoch 98 Step 40/1563 Loss 0.9308 Accuracy 0.6562
# Epoch 98 Step 50/1563 Loss 0.5221 Accuracy 0.8750
# Epoch 98 Step 60/1563 Loss 0.6808 Accuracy 0.8125
# Epoch 98 Step 70/1563 Loss 0.9522 Accuracy 0.6562
# Epoch 98 Step 80/1563 Loss 0.6334 Accuracy 0.7812
# Epoch 98 Step 90/1563 Loss 0.4489 Accuracy 0.8125
# Epoch 98 Step 100/1563 Loss 1.1063 Accuracy 0.6875
# Epoch 98 Step 110/1563 Loss 0.6300 Accuracy 0.7500
# Epoch 98 Step 120/1563 Loss 0.6506 Accuracy 0.7500
# Epoch 98 Step 130/1563 Loss 0.6514 Accuracy 0.7812
# Epoch 98 Step 140/1563 Loss 0.7874 Accuracy 0.6562
# Epoch 98 Step 150/1563 Loss 0.7873 Accuracy 0.7812
# Epoch 98 Step 160/1563 Loss 0.7247 Accuracy 0.7500
# Epoch 98 Step 170/1563 Loss 0.8569 Accuracy 0.7188
# Epoch 98 Step 180/1563 Loss 0.9692 Accuracy 0.7188
# Epoch 98 Step 190/1563 Loss 0.5770 Accuracy 0.8125
# Epoch 98 Step 200/1563 Loss 0.3509 Accuracy 0.8750
# Epoch 98 Step 210/1563 Loss 0.3283 Accuracy 0.9062
# Epoch 98 Step 220/1563 Loss 0.5800 Accuracy 0.8438
# Epoch 98 Step 230/1563 Loss 0.7535 Accuracy 0.7188
# Epoch 98 Step 240/1563 Loss 0.9087 Accuracy 0.6250
# Epoch 98 Step 250/1563 Loss 0.5858 Accuracy 0.9062
# Epoch 98 Step 260/1563 Loss 0.4909 Accuracy 0.8438
# Epoch 98 Step 270/1563 Loss 0.6685 Accuracy 0.8750
# Epoch 98 Step 280/1563 Loss 0.8042 Accuracy 0.6875
# Epoch 98 Step 290/1563 Loss 0.8257 Accuracy 0.6250
# Epoch 98 Step 300/1563 Loss 0.9709 Accuracy 0.6250
# Epoch 98 Step 310/1563 Loss 0.4263 Accuracy 0.8750
# Epoch 98 Step 320/1563 Loss 0.5725 Accuracy 0.8125
# Epoch 98 Step 330/1563 Loss 1.3346 Accuracy 0.7500
# Epoch 98 Step 340/1563 Loss 0.8178 Accuracy 0.6875
# Epoch 98 Step 350/1563 Loss 0.7139 Accuracy 0.8125
# Epoch 98 Step 360/1563 Loss 0.6202 Accuracy 0.7812
# Epoch 98 Step 370/1563 Loss 0.6350 Accuracy 0.8438
# Epoch 98 Step 380/1563 Loss 0.8026 Accuracy 0.7188
# Epoch 98 Step 390/1563 Loss 0.8353 Accuracy 0.7500
# Epoch 98 Step 400/1563 Loss 0.4888 Accuracy 0.7812
# Epoch 98 Step 410/1563 Loss 0.6460 Accuracy 0.8125
# Epoch 98 Step 420/1563 Loss 0.5056 Accuracy 0.7812
# Epoch 98 Step 430/1563 Loss 0.3504 Accuracy 0.9062
# Epoch 98 Step 440/1563 Loss 0.6800 Accuracy 0.7500
# Epoch 98 Step 450/1563 Loss 0.9386 Accuracy 0.6562
# Epoch 98 Step 460/1563 Loss 0.6647 Accuracy 0.7500
# Epoch 98 Step 470/1563 Loss 0.6514 Accuracy 0.7188
# Epoch 98 Step 480/1563 Loss 0.5557 Accuracy 0.8125
# Epoch 98 Step 490/1563 Loss 0.9983 Accuracy 0.7500
# Epoch 98 Step 500/1563 Loss 0.6816 Accuracy 0.7500
# Epoch 98 Step 510/1563 Loss 0.5416 Accuracy 0.7812
# Epoch 98 Step 520/1563 Loss 0.4004 Accuracy 0.8750
# Epoch 98 Step 530/1563 Loss 0.9098 Accuracy 0.6875
# Epoch 98 Step 540/1563 Loss 0.5623 Accuracy 0.8125
# Epoch 98 Step 550/1563 Loss 0.7981 Accuracy 0.7500
# Epoch 98 Step 560/1563 Loss 0.6873 Accuracy 0.7812
# Epoch 98 Step 570/1563 Loss 0.5045 Accuracy 0.8125
# Epoch 98 Step 580/1563 Loss 0.6972 Accuracy 0.7812
# Epoch 98 Step 590/1563 Loss 0.7395 Accuracy 0.7500
# Epoch 98 Step 600/1563 Loss 0.5817 Accuracy 0.8125
# Epoch 98 Step 610/1563 Loss 0.6925 Accuracy 0.7812
# Epoch 98 Step 620/1563 Loss 0.8916 Accuracy 0.6250
# Epoch 98 Step 630/1563 Loss 0.5185 Accuracy 0.8125
# Epoch 98 Step 640/1563 Loss 0.6823 Accuracy 0.8125
# Epoch 98 Step 650/1563 Loss 0.9160 Accuracy 0.6875
# Epoch 98 Step 660/1563 Loss 0.6702 Accuracy 0.8125
# Epoch 98 Step 670/1563 Loss 0.5709 Accuracy 0.8750
# Epoch 98 Step 680/1563 Loss 0.4487 Accuracy 0.8125
# Epoch 98 Step 690/1563 Loss 0.7996 Accuracy 0.7188
# Epoch 98 Step 700/1563 Loss 0.7885 Accuracy 0.7188
# Epoch 98 Step 710/1563 Loss 0.6540 Accuracy 0.7188
# Epoch 98 Step 720/1563 Loss 1.1913 Accuracy 0.5625
# Epoch 98 Step 730/1563 Loss 1.1585 Accuracy 0.5938
# Epoch 98 Step 740/1563 Loss 0.8096 Accuracy 0.7812
# Epoch 98 Step 750/1563 Loss 0.3129 Accuracy 0.9688
# Epoch 98 Step 760/1563 Loss 0.7629 Accuracy 0.5625
# Epoch 98 Step 770/1563 Loss 0.6717 Accuracy 0.8125
# Epoch 98 Step 780/1563 Loss 0.8066 Accuracy 0.7188
# Epoch 98 Step 790/1563 Loss 0.9044 Accuracy 0.7188
# Epoch 98 Step 800/1563 Loss 0.8066 Accuracy 0.7812
# Epoch 98 Step 810/1563 Loss 0.6402 Accuracy 0.7500
# Epoch 98 Step 820/1563 Loss 0.6687 Accuracy 0.8125
# Epoch 98 Step 830/1563 Loss 1.1811 Accuracy 0.5938
# Epoch 98 Step 840/1563 Loss 0.4944 Accuracy 0.8438
# Epoch 98 Step 850/1563 Loss 0.6225 Accuracy 0.7812
# Epoch 98 Step 860/1563 Loss 0.7609 Accuracy 0.8125
# Epoch 98 Step 870/1563 Loss 0.8113 Accuracy 0.7188
# Epoch 98 Step 880/1563 Loss 0.6271 Accuracy 0.8125
# Epoch 98 Step 890/1563 Loss 0.4922 Accuracy 0.8750
# Epoch 98 Step 900/1563 Loss 0.6067 Accuracy 0.8438
# Epoch 98 Step 910/1563 Loss 0.8150 Accuracy 0.7188
# Epoch 98 Step 920/1563 Loss 0.6724 Accuracy 0.7188
# Epoch 98 Step 930/1563 Loss 0.6753 Accuracy 0.7500
# Epoch 98 Step 940/1563 Loss 0.6102 Accuracy 0.7500
# Epoch 98 Step 950/1563 Loss 0.4982 Accuracy 0.8125
# Epoch 98 Step 960/1563 Loss 0.6503 Accuracy 0.7500
# Epoch 98 Step 970/1563 Loss 0.7042 Accuracy 0.6875
# Epoch 98 Step 980/1563 Loss 0.4765 Accuracy 0.8438
# Epoch 98 Step 990/1563 Loss 0.7822 Accuracy 0.7188
# Epoch 98 Step 1000/1563 Loss 1.0327 Accuracy 0.5312
# Epoch 98 Step 1010/1563 Loss 0.6130 Accuracy 0.8125
# Epoch 98 Step 1020/1563 Loss 0.6954 Accuracy 0.7188
# Epoch 98 Step 1030/1563 Loss 0.7973 Accuracy 0.7188
# Epoch 98 Step 1040/1563 Loss 0.6134 Accuracy 0.7188
# Epoch 98 Step 1050/1563 Loss 1.1010 Accuracy 0.6250
# Epoch 98 Step 1060/1563 Loss 0.6621 Accuracy 0.7500
# Epoch 98 Step 1070/1563 Loss 0.8287 Accuracy 0.6875
# Epoch 98 Step 1080/1563 Loss 0.6266 Accuracy 0.8750
# Epoch 98 Step 1090/1563 Loss 0.6812 Accuracy 0.8125
# Epoch 98 Step 1100/1563 Loss 0.6496 Accuracy 0.7812
# Epoch 98 Step 1110/1563 Loss 0.6944 Accuracy 0.7812
# Epoch 98 Step 1120/1563 Loss 0.6474 Accuracy 0.7500
# Epoch 98 Step 1130/1563 Loss 1.0336 Accuracy 0.6875
# Epoch 98 Step 1140/1563 Loss 0.5464 Accuracy 0.8438
# Epoch 98 Step 1150/1563 Loss 0.8141 Accuracy 0.6875
# Epoch 98 Step 1160/1563 Loss 0.6192 Accuracy 0.8125
# Epoch 98 Step 1170/1563 Loss 0.6508 Accuracy 0.7500
# Epoch 98 Step 1180/1563 Loss 0.4564 Accuracy 0.9062
# Epoch 98 Step 1190/1563 Loss 0.6047 Accuracy 0.7812
# Epoch 98 Step 1200/1563 Loss 0.4485 Accuracy 0.8125
# Epoch 98 Step 1210/1563 Loss 0.9605 Accuracy 0.6875
# Epoch 98 Step 1220/1563 Loss 0.6902 Accuracy 0.8438
# Epoch 98 Step 1230/1563 Loss 0.3803 Accuracy 0.8750
# Epoch 98 Step 1240/1563 Loss 0.6962 Accuracy 0.7188
# Epoch 98 Step 1250/1563 Loss 0.7304 Accuracy 0.8125
# Epoch 98 Step 1260/1563 Loss 0.4730 Accuracy 0.9062
# Epoch 98 Step 1270/1563 Loss 0.7765 Accuracy 0.6875
# Epoch 98 Step 1280/1563 Loss 0.7288 Accuracy 0.7500
# Epoch 98 Step 1290/1563 Loss 0.7907 Accuracy 0.7500
# Epoch 98 Step 1300/1563 Loss 0.9573 Accuracy 0.7188
# Epoch 98 Step 1310/1563 Loss 0.5836 Accuracy 0.7500
# Epoch 98 Step 1320/1563 Loss 0.6271 Accuracy 0.7500
# Epoch 98 Step 1330/1563 Loss 0.9919 Accuracy 0.7188
# Epoch 98 Step 1340/1563 Loss 0.8800 Accuracy 0.6562
# Epoch 98 Step 1350/1563 Loss 0.7512 Accuracy 0.6562
# Epoch 98 Step 1360/1563 Loss 0.9662 Accuracy 0.6875
# Epoch 98 Step 1370/1563 Loss 0.7432 Accuracy 0.7500
# Epoch 98 Step 1380/1563 Loss 0.6898 Accuracy 0.7812
# Epoch 98 Step 1390/1563 Loss 0.6099 Accuracy 0.8125
# Epoch 98 Step 1400/1563 Loss 0.6572 Accuracy 0.8438
# Epoch 98 Step 1410/1563 Loss 0.8626 Accuracy 0.6250
# Epoch 98 Step 1420/1563 Loss 0.6237 Accuracy 0.8125
# Epoch 98 Step 1430/1563 Loss 0.5827 Accuracy 0.8750
# Epoch 98 Step 1440/1563 Loss 0.7677 Accuracy 0.7500
# Epoch 98 Step 1450/1563 Loss 0.9358 Accuracy 0.6562
# Epoch 98 Step 1460/1563 Loss 0.7240 Accuracy 0.8125
# Epoch 98 Step 1470/1563 Loss 0.3987 Accuracy 0.9062
# Epoch 98 Step 1480/1563 Loss 0.3504 Accuracy 0.9375
# Epoch 98 Step 1490/1563 Loss 0.6059 Accuracy 0.8125
# Epoch 98 Step 1500/1563 Loss 0.6660 Accuracy 0.8438
# Epoch 98 Step 1510/1563 Loss 0.9308 Accuracy 0.6875
# Epoch 98 Step 1520/1563 Loss 0.7309 Accuracy 0.7500
# Epoch 98 Step 1530/1563 Loss 0.7095 Accuracy 0.7500
# Epoch 98 Step 1540/1563 Loss 0.7768 Accuracy 0.6875
# Epoch 98 Step 1550/1563 Loss 0.6712 Accuracy 0.8438
# Epoch 98 Step 1560/1563 Loss 0.8009 Accuracy 0.6875
# Epoch 98 / Accuracy 0.7147
# Epoch 99 Step 0/1563 Loss 0.7360 Accuracy 0.8125
# Epoch 99 Step 10/1563 Loss 0.7514 Accuracy 0.7812
# Epoch 99 Step 20/1563 Loss 0.7238 Accuracy 0.7812
# Epoch 99 Step 30/1563 Loss 0.5127 Accuracy 0.8750
# Epoch 99 Step 40/1563 Loss 0.7591 Accuracy 0.7500
# Epoch 99 Step 50/1563 Loss 0.4132 Accuracy 0.9062
# Epoch 99 Step 60/1563 Loss 0.5228 Accuracy 0.7812
# Epoch 99 Step 70/1563 Loss 0.4886 Accuracy 0.8438
# Epoch 99 Step 80/1563 Loss 0.5102 Accuracy 0.8438
# Epoch 99 Step 90/1563 Loss 0.6455 Accuracy 0.7812
# Epoch 99 Step 100/1563 Loss 0.8792 Accuracy 0.6875
# Epoch 99 Step 110/1563 Loss 0.4532 Accuracy 0.7812
# Epoch 99 Step 120/1563 Loss 0.7570 Accuracy 0.7188
# Epoch 99 Step 130/1563 Loss 1.0497 Accuracy 0.6875
# Epoch 99 Step 140/1563 Loss 0.9166 Accuracy 0.7812
# Epoch 99 Step 150/1563 Loss 0.6508 Accuracy 0.7812
# Epoch 99 Step 160/1563 Loss 0.5730 Accuracy 0.7812
# Epoch 99 Step 170/1563 Loss 0.7646 Accuracy 0.7188
# Epoch 99 Step 180/1563 Loss 0.7435 Accuracy 0.6875
# Epoch 99 Step 190/1563 Loss 0.7669 Accuracy 0.7812
# Epoch 99 Step 200/1563 Loss 0.7647 Accuracy 0.8125
# Epoch 99 Step 210/1563 Loss 1.0186 Accuracy 0.7188
# Epoch 99 Step 220/1563 Loss 0.6198 Accuracy 0.7188
# Epoch 99 Step 230/1563 Loss 0.5555 Accuracy 0.7812
# Epoch 99 Step 240/1563 Loss 0.6764 Accuracy 0.8125
# Epoch 99 Step 250/1563 Loss 0.9036 Accuracy 0.6250
# Epoch 99 Step 260/1563 Loss 0.5841 Accuracy 0.8125
# Epoch 99 Step 270/1563 Loss 0.6770 Accuracy 0.7500
# Epoch 99 Step 280/1563 Loss 0.7760 Accuracy 0.6250
# Epoch 99 Step 290/1563 Loss 0.5631 Accuracy 0.8125
# Epoch 99 Step 300/1563 Loss 0.9761 Accuracy 0.7188
# Epoch 99 Step 310/1563 Loss 0.5821 Accuracy 0.8125
# Epoch 99 Step 320/1563 Loss 0.7567 Accuracy 0.7812
# Epoch 99 Step 330/1563 Loss 0.5580 Accuracy 0.7812
# Epoch 99 Step 340/1563 Loss 0.5621 Accuracy 0.8438
# Epoch 99 Step 350/1563 Loss 0.5557 Accuracy 0.7500
# Epoch 99 Step 360/1563 Loss 0.6699 Accuracy 0.8125
# Epoch 99 Step 370/1563 Loss 0.6557 Accuracy 0.6875
# Epoch 99 Step 380/1563 Loss 0.7038 Accuracy 0.7812
# Epoch 99 Step 390/1563 Loss 0.7607 Accuracy 0.8125
# Epoch 99 Step 400/1563 Loss 0.8490 Accuracy 0.7500
# Epoch 99 Step 410/1563 Loss 0.8058 Accuracy 0.7812
# Epoch 99 Step 420/1563 Loss 0.5533 Accuracy 0.7812
# Epoch 99 Step 430/1563 Loss 0.5640 Accuracy 0.8438
# Epoch 99 Step 440/1563 Loss 0.6525 Accuracy 0.7812
# Epoch 99 Step 450/1563 Loss 0.4659 Accuracy 0.8438
# Epoch 99 Step 460/1563 Loss 0.5862 Accuracy 0.7188
# Epoch 99 Step 470/1563 Loss 1.0188 Accuracy 0.5938
# Epoch 99 Step 480/1563 Loss 0.7616 Accuracy 0.7500
# Epoch 99 Step 490/1563 Loss 1.2637 Accuracy 0.6562
# Epoch 99 Step 500/1563 Loss 0.5040 Accuracy 0.8438
# Epoch 99 Step 510/1563 Loss 0.3955 Accuracy 0.8438
# Epoch 99 Step 520/1563 Loss 0.7857 Accuracy 0.7500
# Epoch 99 Step 530/1563 Loss 0.8883 Accuracy 0.6562
# Epoch 99 Step 540/1563 Loss 1.0271 Accuracy 0.6875
# Epoch 99 Step 550/1563 Loss 0.8207 Accuracy 0.6875
# Epoch 99 Step 560/1563 Loss 0.8379 Accuracy 0.7500
# Epoch 99 Step 570/1563 Loss 0.6400 Accuracy 0.8125
# Epoch 99 Step 580/1563 Loss 0.8704 Accuracy 0.7812
# Epoch 99 Step 590/1563 Loss 0.7288 Accuracy 0.7500
# Epoch 99 Step 600/1563 Loss 0.4009 Accuracy 0.9062
# Epoch 99 Step 610/1563 Loss 0.7651 Accuracy 0.7500
# Epoch 99 Step 620/1563 Loss 0.7987 Accuracy 0.7188
# Epoch 99 Step 630/1563 Loss 0.7938 Accuracy 0.6250
# Epoch 99 Step 640/1563 Loss 0.6197 Accuracy 0.6875
# Epoch 99 Step 650/1563 Loss 0.7066 Accuracy 0.7812
# Epoch 99 Step 660/1563 Loss 0.3979 Accuracy 0.8438
# Epoch 99 Step 670/1563 Loss 1.0434 Accuracy 0.7188
# Epoch 99 Step 680/1563 Loss 0.4935 Accuracy 0.8438
# Epoch 99 Step 690/1563 Loss 0.4920 Accuracy 0.8125
# Epoch 99 Step 700/1563 Loss 0.7589 Accuracy 0.7188
# Epoch 99 Step 710/1563 Loss 0.7478 Accuracy 0.8125
# Epoch 99 Step 720/1563 Loss 0.7066 Accuracy 0.8125
# Epoch 99 Step 730/1563 Loss 1.0386 Accuracy 0.6250
# Epoch 99 Step 740/1563 Loss 0.6162 Accuracy 0.8125
# Epoch 99 Step 750/1563 Loss 0.5839 Accuracy 0.8438
# Epoch 99 Step 760/1563 Loss 1.0464 Accuracy 0.7500
# Epoch 99 Step 770/1563 Loss 0.6776 Accuracy 0.7500
# Epoch 99 Step 780/1563 Loss 0.6050 Accuracy 0.8125
# Epoch 99 Step 790/1563 Loss 0.7571 Accuracy 0.7812
# Epoch 99 Step 800/1563 Loss 0.5665 Accuracy 0.8125
# Epoch 99 Step 810/1563 Loss 0.7612 Accuracy 0.7500
# Epoch 99 Step 820/1563 Loss 0.6264 Accuracy 0.7812
# Epoch 99 Step 830/1563 Loss 0.9045 Accuracy 0.8438
# Epoch 99 Step 840/1563 Loss 0.6245 Accuracy 0.7812
# Epoch 99 Step 850/1563 Loss 0.7250 Accuracy 0.7500
# Epoch 99 Step 860/1563 Loss 0.7974 Accuracy 0.7812
# Epoch 99 Step 870/1563 Loss 0.4569 Accuracy 0.8438
# Epoch 99 Step 880/1563 Loss 0.4010 Accuracy 0.8438
# Epoch 99 Step 890/1563 Loss 0.9844 Accuracy 0.6250
# Epoch 99 Step 900/1563 Loss 0.5016 Accuracy 0.8125
# Epoch 99 Step 910/1563 Loss 0.6209 Accuracy 0.7500
# Epoch 99 Step 920/1563 Loss 0.3819 Accuracy 0.8750
# Epoch 99 Step 930/1563 Loss 0.8851 Accuracy 0.6250
# Epoch 99 Step 940/1563 Loss 0.7443 Accuracy 0.6562
# Epoch 99 Step 950/1563 Loss 0.5896 Accuracy 0.8125
# Epoch 99 Step 960/1563 Loss 0.6288 Accuracy 0.6875
# Epoch 99 Step 970/1563 Loss 0.7432 Accuracy 0.7500
# Epoch 99 Step 980/1563 Loss 0.5395 Accuracy 0.7500
# Epoch 99 Step 990/1563 Loss 0.6700 Accuracy 0.7188
# Epoch 99 Step 1000/1563 Loss 0.8521 Accuracy 0.7188
# Epoch 99 Step 1010/1563 Loss 0.9074 Accuracy 0.7188
# Epoch 99 Step 1020/1563 Loss 0.9075 Accuracy 0.6562
# Epoch 99 Step 1030/1563 Loss 0.5521 Accuracy 0.8438
# Epoch 99 Step 1040/1563 Loss 0.7269 Accuracy 0.7812
# Epoch 99 Step 1050/1563 Loss 0.7946 Accuracy 0.7812
# Epoch 99 Step 1060/1563 Loss 0.8148 Accuracy 0.7500
# Epoch 99 Step 1070/1563 Loss 0.5783 Accuracy 0.8125
# Epoch 99 Step 1080/1563 Loss 0.7805 Accuracy 0.7500
# Epoch 99 Step 1090/1563 Loss 0.8810 Accuracy 0.7500
# Epoch 99 Step 1100/1563 Loss 0.7211 Accuracy 0.7812
# Epoch 99 Step 1110/1563 Loss 0.7723 Accuracy 0.6875
# Epoch 99 Step 1120/1563 Loss 0.6629 Accuracy 0.7500
# Epoch 99 Step 1130/1563 Loss 1.0584 Accuracy 0.6562
# Epoch 99 Step 1140/1563 Loss 0.5933 Accuracy 0.8125
# Epoch 99 Step 1150/1563 Loss 0.5573 Accuracy 0.8125
# Epoch 99 Step 1160/1563 Loss 0.3530 Accuracy 0.9062
# Epoch 99 Step 1170/1563 Loss 0.5511 Accuracy 0.8125
# Epoch 99 Step 1180/1563 Loss 0.5313 Accuracy 0.7500
# Epoch 99 Step 1190/1563 Loss 0.9065 Accuracy 0.7188
# Epoch 99 Step 1200/1563 Loss 0.7370 Accuracy 0.7500
# Epoch 99 Step 1210/1563 Loss 0.4398 Accuracy 0.8750
# Epoch 99 Step 1220/1563 Loss 0.7636 Accuracy 0.6875
# Epoch 99 Step 1230/1563 Loss 1.0423 Accuracy 0.7500
# Epoch 99 Step 1240/1563 Loss 0.6340 Accuracy 0.7812
# Epoch 99 Step 1250/1563 Loss 0.5661 Accuracy 0.7500
# Epoch 99 Step 1260/1563 Loss 0.9533 Accuracy 0.6250
# Epoch 99 Step 1270/1563 Loss 0.5412 Accuracy 0.7500
# Epoch 99 Step 1280/1563 Loss 0.5956 Accuracy 0.7500
# Epoch 99 Step 1290/1563 Loss 0.6761 Accuracy 0.7188
# Epoch 99 Step 1300/1563 Loss 0.6103 Accuracy 0.7500
# Epoch 99 Step 1310/1563 Loss 0.6173 Accuracy 0.7188
# Epoch 99 Step 1320/1563 Loss 0.7701 Accuracy 0.7812
# Epoch 99 Step 1330/1563 Loss 0.6798 Accuracy 0.7188
# Epoch 99 Step 1340/1563 Loss 0.4820 Accuracy 0.8438
# Epoch 99 Step 1350/1563 Loss 0.9303 Accuracy 0.7188
# Epoch 99 Step 1360/1563 Loss 0.7037 Accuracy 0.8125
# Epoch 99 Step 1370/1563 Loss 0.6541 Accuracy 0.8125
# Epoch 99 Step 1380/1563 Loss 0.9589 Accuracy 0.6562
# Epoch 99 Step 1390/1563 Loss 0.6021 Accuracy 0.8125
# Epoch 99 Step 1400/1563 Loss 0.4442 Accuracy 0.8438
# Epoch 99 Step 1410/1563 Loss 0.5002 Accuracy 0.8125
# Epoch 99 Step 1420/1563 Loss 0.5908 Accuracy 0.7188
# Epoch 99 Step 1430/1563 Loss 1.0271 Accuracy 0.6562
# Epoch 99 Step 1440/1563 Loss 0.7850 Accuracy 0.7500
# Epoch 99 Step 1450/1563 Loss 1.6002 Accuracy 0.5625
# Epoch 99 Step 1460/1563 Loss 0.9737 Accuracy 0.6250
# Epoch 99 Step 1470/1563 Loss 0.6778 Accuracy 0.8125
# Epoch 99 Step 1480/1563 Loss 0.9233 Accuracy 0.6250
# Epoch 99 Step 1490/1563 Loss 0.6333 Accuracy 0.7812
# Epoch 99 Step 1500/1563 Loss 0.6350 Accuracy 0.7812
# Epoch 99 Step 1510/1563 Loss 0.6803 Accuracy 0.7812
# Epoch 99 Step 1520/1563 Loss 0.6634 Accuracy 0.8125
# Epoch 99 Step 1530/1563 Loss 1.0697 Accuracy 0.6875
# Epoch 99 Step 1540/1563 Loss 0.7584 Accuracy 0.7812
# Epoch 99 Step 1550/1563 Loss 0.5570 Accuracy 0.7188
# Epoch 99 Step 1560/1563 Loss 0.7977 Accuracy 0.7188
# Epoch 99 / Accuracy 0.7157

# %% [markdown]
# ##### 학습된 Convolution 가중치 확인

# %%
def plot_tensor(tensor, mode=1, num_col=None, label=None):
    tensor = tensor.detach().cpu()  ## detach from tensor graph
    img_grid = torchvision.utils.make_grid(tensor, nrow=num_col, padding=2, pad_value=1, normalize=True)

    plt.imshow(img_grid.permute(1, 2, 0))
    plt.axis('off')
    plt.tight_layout()
    plt.show()

# %%
state_dict = torch.load('./ckpt/model_state_99.st')
model.load_state_dict(state_dict, strict=True)
weight_tensor = model.conv1.weight
plot_tensor(weight_tensor, mode=2, num_col=4)
# Out:
# C:\Users\perso\AppData\Local\Temp\ipykernel_33256\894903236.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load('./ckpt/model_state_99.st')

# %% [markdown]
# ##### 테스트

# %%
classes = ('plane','car','bird','cat','deer','dog','frog','horse','ship','truck')
model.eval()

with torch.no_grad():
    for step, (data, targets) in enumerate(testloader):
        data = data.to(device, dtype=torch.float)
        output, _ = model(data)
        _, pred = output.topk(1, 1, True, True)
        target_cls = [classes[x] for x in targets.cpu().numpy()]
        pred_cls = [classes[x] for x in pred.cpu().squeeze().numpy()]

        print(target_cls, pred_cls, sep='\n')

        plot_tensor(data, mode=2, num_col=4, label=[target_cls, pred_cls])
        break
# Out:
# ['cat', 'ship', 'ship', 'plane', 'frog', 'frog', 'car', 'frog', 'cat', 'car', 'plane', 'truck', 'dog', 'horse', 'truck', 'ship', 'dog', 'horse', 'ship', 'frog', 'horse', 'plane', 'deer', 'truck', 'dog', 'bird', 'deer', 'plane', 'truck', 'frog', 'frog', 'dog']
# ['cat', 'ship', 'ship', 'plane', 'frog', 'frog', 'car', 'frog', 'cat', 'truck', 'plane', 'truck', 'cat', 'horse', 'truck', 'deer', 'dog', 'dog', 'ship', 'frog', 'horse', 'plane', 'bird', 'truck', 'deer', 'deer', 'deer', 'frog', 'truck', 'frog', 'frog', 'dog']
